# %%
import requests
from bs4 import BeautifulSoup
import time
import csv

# %%
BASE_URL = "https://es.wikipedia.org"
processed_urls = set()

# %%
def obtener_sopa(url, intentos=3):
    """Realiza una solicitud HTTP y devuelve una BeautifulSoup, con reintentos."""
    for intento in range(intentos):
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            return BeautifulSoup(response.text, 'html.parser')
        except requests.exceptions.Timeout:
            print(f"Tiempo de espera agotado para {url}. Reintentando ({intento + 1}/{intentos})...")
            time.sleep(5)
        except requests.RequestException as e:
            print(f"Error al acceder a {url}: {e}")
            return None
    return None


def extraer_familias(sopa):
    """Extrae las familias desde la página principal de categoría."""
    familias = []
    for div in sopa.find_all('div', class_='mw-category-group'):
        for li in div.find_all('li'):
            a_tag = li.find('a')
            if a_tag and 'Familia' in a_tag.text and 'Fundadoras' not in a_tag.text:
                familias.append((a_tag.text.strip(), BASE_URL + a_tag['href']))
    return familias


def extraer_miembros_familia(sopa):
    """
    Extrae recursivamente los miembros de una categoría:
      1) Recorre subcategorías y llama recursivo.
      2) Luego extrae las páginas de 'mw-pages'.
    """
    miembros = set()
    subcat = sopa.find('div', id='mw-subcategories')
    if subcat:
        for div in subcat.find_all('div', class_='mw-category-group'):
            for li in div.find_all('li'):
                a = li.find('a', href=True)
                if a and '/wiki/Categor%C3%ADa:' in a['href']:
                    sub_sopa = obtener_sopa(BASE_URL + a['href'])
                    if sub_sopa:
                        miembros |= extraer_miembros_familia(sub_sopa)
    pages = sopa.find('div', id='mw-pages')
    if pages:
        for div in pages.find_all('div', class_='mw-category-group'):
            for li in div.find_all('li'):
                a = li.find('a', href=True)
                if a:
                    miembros.add((a.text.strip(), BASE_URL + a['href']))
    return miembros


def save_to_csv(info, filename="familias_argentinas.csv"):
    """Guarda un diccionario en el CSV si su URL no se ha procesado aún."""
    if info["URL"] in processed_urls:
        return
    processed_urls.add(info["URL"])

    with open(filename, mode='a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        row = [
            info.get("Nombre", ""),
            info.get("Fecha de nacimiento", ""),
            info.get("Residencia", ""),
            info.get("Nacionalidad", ""),
            info.get("Cargos", ""),
            info.get("Educación", ""),
            info.get("Trabajos previos", ""),
            info.get("Área", ""),
            info.get("Partido político", ""),
            info.get("Familia", ""),
            info.get("Categorías", ""),
            info.get("URL", "")
        ]
        writer.writerow(row)


def dedup_csv(filename="familias_argentinas.csv"):
    """Elimina filas duplicadas en el CSV, basándose en todas las columnas."""
    seen = set()
    unique = []
    with open(filename, newline='', encoding='utf-8') as f:
        reader = csv.reader(f, delimiter=';')
        header = next(reader)
        for row in reader:
            row_tup = tuple(row)
            if row_tup not in seen:
                seen.add(row_tup)
                unique.append(row)
    with open(filename, mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        writer.writerow(header)
        writer.writerows(unique)


def extract_info(url, depth=0, max_depth=1):
    sopa = obtener_sopa(url)
    if not sopa:
        return

    infobox = sopa.find("table", class_="infobox biography vcard")
    if not infobox:
        return

    info = {
        "Nombre": "", "Fecha de nacimiento": "", "Residencia": "",
        "Nacionalidad": "", "Cargos": "", "Educación": "",
        "Trabajos previos": "", "Área": "", "Partido político": "",
        "Familia": "", "Categorías": "", "URL": url
    }

    h1 = sopa.find("h1", class_="firstHeading")
    if h1:
        info["Nombre"] = h1.text.strip()

    cat_div = sopa.find("div", id="mw-normal-catlinks")
    if cat_div:
        info["Categorías"] = "; ".join(a.text for a in cat_div.find_all("a"))

    rows = infobox.find_all("tr")
    for row in rows:
        th = row.find("th")
        td = row.find("td")
        if not th or not td:
            continue
        h = th.text.strip()
        txt = td.get_text(" ", strip=True)

        if "Nacimiento" in h:
            info["Fecha de nacimiento"] = txt
        elif "Residencia" in h:
            info["Residencia"] = txt
        elif "Nacionalidad" in h:
            info["Nacionalidad"] = txt
        elif any(k in h for k in ["Ocupación", "Cargo", "Cargos"]):
            info["Cargos"] = "; ".join(td.stripped_strings)
        elif any(k in h for k in ["Educación", "Educado en", "Educada en"]):
            info["Educación"] = "; ".join(
                a.text for a in td.find_all("a", href=True) if a["href"].startswith("/wiki/")
            )
        elif "Área" in h:
            info["Área"] = txt
        elif "Partido político" in h:
            info["Partido político"] = "; ".join(a.text for a in td.find_all("a", href=True))
        elif any(k in h for k in ["Padres", "Cónyuge", "Hijos", "Familia"]):
            familia = []
            for a in td.find_all("a", href=True):
                href = a["href"]
                if href.startswith("/wiki/") and not any(href.startswith(excl) for excl in [
                        "/wiki/Ayuda:", "/wiki/Archivo:", "/wiki/Especial:",
                        "/wiki/Plantilla:", "/wiki/Portal:", "/wiki/Categor%C3%ADa:", "/wiki/Familia_"
                ]):
                    familia.append(f"{a.text} ({BASE_URL}{href})")
            info["Familia"] = "; ".join(familia)

    for i in range(len(rows)-1):
        th = rows[i].find("th")
        td = rows[i+1].find("td")
        if th and td and th.get("colspan") == "3" and "background-color:#E6E6FA" in th.get("style", ""):
            cargos = "; ".join(a.text for a in th.find_all("a", href=True))
            fechas = td.get_text(" ", strip=True)
            info["Trabajos previos"] += f"{cargos} – {fechas}; "

    save_to_csv(info)
    print(f"Guardado: {info['Nombre']}")

    if depth < max_depth and info["Familia"]:
        for miembro in info["Familia"].split("; "):
            if "(" in miembro and miembro.endswith(")"):
                member_url = miembro.split("(")[1][:-1]
                extract_info(member_url, depth+1, max_depth)
                time.sleep(2)

# %%
def main():
    url_categorias = f'{BASE_URL}/wiki/Categoría:Familias_políticas_de_Argentina'

    # Crear CSV con encabezado
    header = [
        "Nombre", "Fecha de nacimiento", "Residencia", "Nacionalidad",
        "Cargos", "Educación", "Trabajos previos", "Área",
        "Partido político", "Familia", "Categorías", "URL"
    ]
    with open("familias_argentinas.csv", mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        writer.writerow(header)

    sopa_principal = obtener_sopa(url_categorias)
    if not sopa_principal:
        print("No se pudo cargar la categoría principal.")
        return

    familias = extraer_familias(sopa_principal)
    for fam_nombre, fam_url in familias:
        print(f"Procesando miembros de {fam_nombre}...")
        sopa_fam = obtener_sopa(fam_url)
        if not sopa_fam:
            continue
        miembros = extraer_miembros_familia(sopa_fam)
        for _, miembro_url in miembros:
            extract_info(miembro_url, depth=0, max_depth=1)
            time.sleep(1)

    # Eliminar duplicados finales
    dedup_csv("familias_argentinas.csv")
    print("Extracción completa. CSV limpio y sin duplicados listo.")

if __name__ == '__main__':
    main()
# Out:
# Procesando miembros de Familia Abal Medina...
# Guardado: Fernando Abal Medina
# Guardado: Juan Manuel Abal Medina
# Guardado: Nilda Garré
# Guardado: Juan Manuel Abal Medina (hijo)
# Guardado: Juan Manuel Abal Medina
# Guardado: Fernando Abal Medina
# Procesando miembros de Familia Alsogaray...
# Guardado: Álvaro José de Alzogaray
# Guardado: Álvaro Alsogaray
# Guardado: María Julia Alsogaray
# Guardado: María Julia Alsogaray
# Guardado: Álvaro Alsogaray
# Guardado: Julio Rodolfo Alsogaray
# Guardado: Álvaro José de Alzogaray
# Guardado: Álvaro José de Alzogaray
# Guardado: Adriana Cecilia Barcia
# Procesando miembros de Familia Astigueta...
# Guardado: José Manuel Astigueta (hijo)
# Guardado: José Mariano Astigueta (nieto)
# Guardado: José Mariano Astigueta (padre)
# Guardado: José Manuel Astigueta (padre)
# Guardado: José Manuel Astigueta (padre)
# Procesando miembros de Familia Bullrich...
# Guardado: Silvina Bullrich
# Guardado: Arturo Bullrich
# Guardado: Rodolfo Galimberti
# Guardado: Patricia Bullrich
# Guardado: Esteban Bullrich
# Guardado: Arturo Bullrich
# Guardado: Fabiana Cantilo
# Guardado: Alfredo Francisco Cantilo
# Guardado: Esteban Bullrich
# Guardado: Augusto Bullrich
# Guardado: Adolfo Bullrich
# Guardado: Francisco Bullrich
# Guardado: Alicia Cazzaniga
# Guardado: Luisa Vehil
# Guardado: Miguel Ángel Solá
# Guardado: Adolfo Bullrich
# Guardado: Augusto Bullrich
# Guardado: Alicia Cazzaniga
# Guardado: Francisco Bullrich
# Procesando miembros de Familia Cafiero...
# Guardado: Juan Pablo Cafiero
# Guardado: Santiago Cafiero
# Guardado: Santiago Cafiero
# Guardado: Mario Cafiero
# Guardado: Antonio Cafiero
# Guardado: Santiago Cafiero
# Procesando miembros de Familia Cámpora...
# Guardado: Héctor José Cámpora
# Guardado: Lucía Cámpora
# Guardado: Mario Cámpora
# Procesando miembros de Familia Caputo...
# Guardado: Santiago Caputo
# Guardado: Luis Caputo
# Guardado: Nicolás Caputo
# Guardado: Dante Caputo
# Guardado: Nicolás Caputo
# Guardado: Luis Caputo
# Guardado: Santiago Caputo
# Guardado: Dante Caputo
# Procesando miembros de Familia Cornejo (Argentina)...
# Guardado: Hernán Hipólito Cornejo
# Guardado: Juan Carlos Cornejo Linares
# Guardado: Hernán Hipólito Cornejo
# Guardado: Lucio Alfredo Cornejo Linares
# Guardado: José Antonio Fernández Cornejo
# Guardado: Gertrudis Medeiros
# Guardado: Julio Cornejo
# Procesando miembros de Familia Daract...
# Guardado: Mauricio Pastor Daract
# Guardado: Justo Daract
# Guardado: Mauricio Daract
# Guardado: Juan Daract
# Guardado: Benito Alberto Nazar Anchorena
# Procesando miembros de Familia Pellegrini...
# Guardado: Carlos Pellegrini
# Guardado: Carlos Meyer Pellegrini
# Guardado: Charles Henri Pellegrini
# Guardado: Carlos Pellegrini
# Procesando miembros de Familia Pinedo...
# Guardado: Agustín de Pinedo
# Guardado: José María Pinedo
# Guardado: Agustín Fernando de Pinedo
# Guardado: Federico Pinedo (hijo)
# Guardado: Federico Pinedo (bisnieto)
# Guardado: Federico Pinedo (padre)
# Procesando miembros de Familia Posse...
# Guardado: Juan Posse
# Guardado: José Víctor Posse
# Guardado: José Posse
# Guardado: Wenceslao Posse
# Procesando miembros de Familia Puch...
# Guardado: Martín Güemes y Puch
# Guardado: Miguel Puch
# Guardado: Domingo Puch Izuleta
# Guardado: Carmen Puch de Güemes
# Guardado: Manuel Puch
# Guardado: Dionisio Puch
# Guardado: Dionisio Puch
# Guardado: Carlos Robledo Puch
# Guardado: Manuel Puch
# Guardado: Carmen Puch de Güemes
# Guardado: Dionisio Puch
# Guardado: Manuel Puch
# Guardado: Martín Gabriel Güemes
# Procesando miembros de Familia Quintana...
# Guardado: Abraham Quintana
# Guardado: Emilio Quintana
# Guardado: Fenelón Quintana
# Guardado: José de la Quintana (político argentino)
# Guardado: Fenelón de la Quintana
# Guardado: Fenelón Quintana
# Guardado: Manuel Rosa de la Quintana
# Guardado: Emilio Quintana
# Guardado: Emilio Quintana (gobernador)
# Procesando miembros de Familia Rocha...
# Guardado: Emilio Castro
# Guardado: Juan José Rosendo Rocha
# Guardado: Juan José Romualdo Rocha
# Guardado: Emilio Castro
# Guardado: Juan José Mariano Rocha
# Guardado: Emilio Castro
# Guardado: Dardo Rocha
# Guardado: Isidro Quesada
# Guardado: Dardo Rocha
# Guardado: Emilio Castro
# Guardado: Miguel Francisco de Villegas
# Guardado: Juan José Mariano Rocha
# Guardado: Juan José Romualdo Rocha
# Guardado: Juan José Romualdo Rocha
# Guardado: Juan José Rosendo Rocha
# Guardado: Emilio Castro
# Guardado: Dardo Rocha
# Procesando miembros de Familia Rodríguez Larreta...
# Guardado: Carlos Rodríguez Larreta
# Guardado: Horacio Rodríguez Larreta
# Guardado: Enrique Larreta
# Guardado: Horacio Rodríguez Larreta
# Guardado: Enrique Larreta
# Guardado: Carlos Rodríguez Larreta
# Guardado: Horacio Rodríguez Larreta
# Guardado: Augusto Larreta
# Guardado: Matilde Rodríguez Larreta
# Guardado: Eduardo Rodríguez Larreta
# Guardado: Antonio Larreta
# Guardado: Horacio Rodríguez Larreta (procurador)
# Guardado: Carlos Rodríguez Larreta
# Guardado: Enrique Larreta
# Guardado: Eduardo Rodríguez Larreta
# Procesando miembros de Familia Rodríguez Saá...
# Guardado: Adolfo Rodríguez Saá "El Pampa"
# Guardado: Humberto Rodríguez Saá
# Guardado: Ricardo Rodríguez Saá
# Guardado: Adolfo Rodríguez Saá
# Guardado: Alberto Rodríguez Saá
# Guardado: Silvia Sapag
# Guardado: Amado Sapag
# Guardado: Edgardo Sapag
# Guardado: Felipe Sapag
# Guardado: Luis Felipe Sapag
# Guardado: Silvia Sapag
# Guardado: Felipe Rodolfo Sapag
# Guardado: Alma Sapag
# Guardado: Elías Sapag
# Guardado: Luz María Sapag
# Guardado: Carmen Lucila Crexell
# Procesando miembros de Familia Snopek...
# Guardado: Guillermo Eugenio Snopek
# Guardado: Guillermo Snopek
# Guardado: Guillermo Snopek
# Guardado: Guillermo Eugenio Snopek
# Guardado: Alejandro Snopek
# Guardado: Gerardo Morales
# Guardado: Carlos Snopek
# Guardado: Guillermo Snopek (padre)
# Guardado: Guillermo Eugenio Snopek
# Procesando miembros de Familia Soria...
# Guardado: María Emilia Soria
# Guardado: Carlos Ernesto Soria
# Guardado: Susana Freydoz
# Guardado: Carlos Ernesto Soria
# Guardado: María Emilia Soria
# Guardado: Martín Soria
# Guardado: Martín Soria
# Guardado: Carlos Ernesto Soria
# Guardado: Susana Freydoz
# Guardado: Susana Freydoz
# Guardado: María Emilia Soria
# Guardado: Martín Soria
# Procesando miembros de Familia Uñac...
# Guardado: José Rubén Uñac
# Guardado: Sergio Uñac
# Guardado: Sergio Uñac
# Procesando miembros de Familia Uriburu...
# Guardado: Napoleón Uriburu
# Guardado: Evaristo de Uriburu
# Guardado: María Josefa Álvarez de Arenales
# Guardado: Clara Agustina de Uriburu Roca
# Guardado: José Camilo Uriburu
# Guardado: Francisco Uriburu
# Guardado: Enrique Uriburu
# Guardado: Raúl Prébisch
# Guardado: Federico José Uriburu
# Guardado: José Félix Uriburu
# Guardado: José Evaristo Uriburu
# Guardado: Pío Uriburu
# Guardado: José Alberto Uriburu
# Guardado: José María Uriburu
# Guardado: José Evaristo Uriburu Tezanos Pinto
# Guardado: Clara Agustina de Uriburu Roca
# Guardado: José Evaristo Uriburu Roca
# Guardado: Alberto Ezcurra Uriburu
# Guardado: Virgilio Mariano Tedín
# Guardado: Juan Nepomuceno Uriburu
# Guardado: María Josefa Álvarez de Arenales
# Guardado: José Evaristo Uriburu
# Guardado: Napoleón Uriburu
# Guardado: Carlos Ibarguren
# Guardado: Evaristo de Uriburu
# Guardado: José Evaristo Uriburu
# Guardado: Napoleón Uriburu
# Guardado: José Evaristo Uriburu
# Guardado: José Félix Uriburu
# Guardado: Francisco Uriburu (hijo)
# Guardado: Francisco Uriburu
# Procesando miembros de Familia Yoma...
# Guardado: Zulema Menem
# Guardado: Carlos Menem Jr.
# Guardado: Eduardo Menem
# Guardado: Munir Menem
# Guardado: Martín Menem
# Guardado: Jorge Yoma
# Guardado: Emir Yoma
# Guardado: Zulema Fátima Yoma
# Guardado: Eduardo Menem
# Guardado: Munir Menem
# Guardado: Carlos Menem Jr.
# Guardado: Eduardo Menem
# Guardado: Munir Menem
# Guardado: Zulema Menem
# Guardado: Amira Yoma
# Extracción completa. CSV limpio y sin duplicados listo.
