# %%
import requests
from bs4 import BeautifulSoup
import time
import csv

# %%
BASE_URL = "https://es.wikipedia.org"
processed_urls = set()

# %%
def obtener_sopa(url, intentos=3):
    """Realiza una solicitud HTTP y devuelve una BeautifulSoup, con reintentos."""
    for intento in range(intentos):
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            return BeautifulSoup(response.text, 'html.parser')
        except requests.exceptions.Timeout:
            print(f"Tiempo de espera agotado para {url}. Reintentando ({intento + 1}/{intentos})...")
            time.sleep(5)
        except requests.RequestException as e:
            print(f"Error al acceder a {url}: {e}")
            return None
    return None


def extraer_familias(sopa):
    """Extrae las familias desde la página principal de categoría."""
    familias = []
    for div in sopa.find_all('div', class_='mw-category-group'):
        for li in div.find_all('li'):
            a_tag = li.find('a')
            if a_tag and 'Familia' in a_tag.text and 'Fundadoras' not in a_tag.text:
                familias.append((a_tag.text.strip(), BASE_URL + a_tag['href']))
    return familias


def extraer_miembros_familia(sopa):
    """
    Extrae recursivamente los miembros de una categoría:
      1) Recorre subcategorías y llama recursivo.
      2) Luego extrae las páginas de 'mw-pages'.
    """
    miembros = set()
    subcat = sopa.find('div', id='mw-subcategories')
    if subcat:
        for div in subcat.find_all('div', class_='mw-category-group'):
            for li in div.find_all('li'):
                a = li.find('a', href=True)
                if a and '/wiki/Categor%C3%ADa:' in a['href']:
                    sub_sopa = obtener_sopa(BASE_URL + a['href'])
                    if sub_sopa:
                        miembros |= extraer_miembros_familia(sub_sopa)
    pages = sopa.find('div', id='mw-pages')
    if pages:
        for div in pages.find_all('div', class_='mw-category-group'):
            for li in div.find_all('li'):
                a = li.find('a', href=True)
                if a:
                    miembros.add((a.text.strip(), BASE_URL + a['href']))
    return miembros


def save_to_csv(info, filename="familias_peru.csv"):
    """Guarda un diccionario en el CSV si su URL no se ha procesado aún."""
    if info["URL"] in processed_urls:
        return
    processed_urls.add(info["URL"])

    with open(filename, mode='a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        row = [
            info.get("Nombre", ""),
            info.get("Fecha de nacimiento", ""),
            info.get("Residencia", ""),
            info.get("Nacionalidad", ""),
            info.get("Cargos", ""),
            info.get("Educación", ""),
            info.get("Trabajos previos", ""),
            info.get("Área", ""),
            info.get("Partido político", ""),
            info.get("Familia", ""),
            info.get("Categorías", ""),
            info.get("URL", "")
        ]
        writer.writerow(row)


def dedup_csv(filename="familias_peru.csv"):
    """Elimina filas duplicadas en el CSV, basándose en todas las columnas."""
    seen = set()
    unique = []
    with open(filename, newline='', encoding='utf-8') as f:
        reader = csv.reader(f, delimiter=';')
        header = next(reader)
        for row in reader:
            row_tup = tuple(row)
            if row_tup not in seen:
                seen.add(row_tup)
                unique.append(row)
    with open(filename, mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        writer.writerow(header)
        writer.writerows(unique)


def extract_info(url, depth=0, max_depth=1):
    sopa = obtener_sopa(url)
    if not sopa:
        return

    infobox = sopa.find("table", class_="infobox biography vcard")
    if not infobox:
        return

    info = {
        "Nombre": "", "Fecha de nacimiento": "", "Residencia": "",
        "Nacionalidad": "", "Cargos": "", "Educación": "",
        "Trabajos previos": "", "Área": "", "Partido político": "",
        "Familia": "", "Categorías": "", "URL": url
    }

    h1 = sopa.find("h1", class_="firstHeading")
    if h1:
        info["Nombre"] = h1.text.strip()

    cat_div = sopa.find("div", id="mw-normal-catlinks")
    if cat_div:
        info["Categorías"] = "; ".join(a.text for a in cat_div.find_all("a"))

    rows = infobox.find_all("tr")
    for row in rows:
        th = row.find("th")
        td = row.find("td")
        if not th or not td:
            continue
        h = th.text.strip()
        txt = td.get_text(" ", strip=True)

        if "Nacimiento" in h:
            info["Fecha de nacimiento"] = txt
        elif "Residencia" in h:
            info["Residencia"] = txt
        elif "Nacionalidad" in h:
            info["Nacionalidad"] = txt
        elif any(k in h for k in ["Ocupación", "Cargo", "Cargos"]):
            info["Cargos"] = "; ".join(td.stripped_strings)
        elif any(k in h for k in ["Educación", "Educado en", "Educada en"]):
            info["Educación"] = "; ".join(
                a.text for a in td.find_all("a", href=True) if a["href"].startswith("/wiki/")
            )
        elif "Área" in h:
            info["Área"] = txt
        elif "Partido político" in h:
            info["Partido político"] = "; ".join(a.text for a in td.find_all("a", href=True))
        elif any(k in h for k in ["Padres", "Cónyuge", "Hijos", "Familia"]):
            familia = []
            for a in td.find_all("a", href=True):
                href = a["href"]
                if href.startswith("/wiki/") and not any(href.startswith(excl) for excl in [
                        "/wiki/Ayuda:", "/wiki/Archivo:", "/wiki/Especial:",
                        "/wiki/Plantilla:", "/wiki/Portal:", "/wiki/Categor%C3%ADa:", "/wiki/Familia_"
                ]):
                    familia.append(f"{a.text} ({BASE_URL}{href})")
            info["Familia"] = "; ".join(familia)

    for i in range(len(rows)-1):
        th = rows[i].find("th")
        td = rows[i+1].find("td")
        if th and td and th.get("colspan") == "3" and "background-color:#E6E6FA" in th.get("style", ""):
            cargos = "; ".join(a.text for a in th.find_all("a", href=True))
            fechas = td.get_text(" ", strip=True)
            info["Trabajos previos"] += f"{cargos} – {fechas}; "

    save_to_csv(info)
    print(f"Guardado: {info['Nombre']}")

    if depth < max_depth and info["Familia"]:
        for miembro in info["Familia"].split("; "):
            if "(" in miembro and miembro.endswith(")"):
                member_url = miembro.split("(")[1][:-1]
                extract_info(member_url, depth+1, max_depth)
                time.sleep(2)

# %%
def main():
    url_categorias = f'{BASE_URL}/wiki/Categoría:Familias_de_Perú'

    # Crear CSV con encabezado
    header = [
        "Nombre", "Fecha de nacimiento", "Residencia", "Nacionalidad",
        "Cargos", "Educación", "Trabajos previos", "Área",
        "Partido político", "Familia", "Categorías", "URL"
    ]
    with open("familias_familias_peru.csv", mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        writer.writerow(header)

    sopa_principal = obtener_sopa(url_categorias)
    if not sopa_principal:
        print("No se pudo cargar la categoría principal.")
        return

    familias = extraer_familias(sopa_principal)
    for fam_nombre, fam_url in familias:
        print(f"Procesando miembros de {fam_nombre}...")
        sopa_fam = obtener_sopa(fam_url)
        if not sopa_fam:
            continue
        miembros = extraer_miembros_familia(sopa_fam)
        for _, miembro_url in miembros:
            extract_info(miembro_url, depth=0, max_depth=1)
            time.sleep(1)

    # Eliminar duplicados finales
    dedup_csv("familias_peru.csv")
    print("Extracción completa. CSV limpio y sin duplicados listo.")

if __name__ == '__main__':
    main()
# Out:
# Procesando miembros de Familia Acurio...
# Guardado: Héctor Acurio Cruz
# Guardado: Jorge Acurio Tito
# Guardado: Gastón Acurio Velarde
# Guardado: Gastón Acurio Jaramillo
# Guardado: Tomás Acurio Arguedas
# Guardado: Gastón Acurio Jaramillo
# Procesando miembros de Familia Acuña...
# Guardado: Virgilio Acuña
# Guardado: César Acuña
# Guardado: Héctor Acuña Peralta
# Guardado: Humberto Acuña
# Guardado: Mary Acuña
# Guardado: César Acuña
# Guardado: Virgilio Acuña
# Guardado: Humberto Acuña
# Guardado: Héctor Acuña Peralta
# Guardado: Mary Acuña
# Guardado: Mary Acuña
# Guardado: César Acuña
# Guardado: Virgilio Acuña
# Guardado: Humberto Acuña
# Guardado: Héctor Acuña Peralta
# Guardado: Carlos Boloña
# Guardado: Joanna Boloña
# Guardado: Héctor Acuña Peralta
# Guardado: César Acuña
# Guardado: Virgilio Acuña
# Guardado: Humberto Acuña
# Guardado: Mary Acuña
# Guardado: Richard Acuña
# Guardado: Humberto Acuña
# Guardado: César Acuña
# Guardado: Virgilio Acuña
# Guardado: Héctor Acuña Peralta
# Guardado: Mary Acuña
# Procesando miembros de Familia Alva...
# Guardado: Bertha Arroyo de Alva
# Guardado: Javier Alva Orlandini
# Guardado: Miguel Alva Orlandini
# Guardado: Luis Alva Castro
# Guardado: Miguel Alva Orlandini
# Guardado: Javier Alva Orlandini
# Guardado: Alejandro Cavero
# Guardado: Maricarmen Alva
# Procesando miembros de Familia Amez...
# Guardado: Alcides Ames Márquez
# Guardado: María Amez Márquez
# Guardado: Carlos Egúsquiza Amez
# Guardado: Nico Ames
# Guardado: María Amez Márquez
# Guardado: Alcides Ames Márquez
# Guardado: Rolando Ames
# Guardado: Lorenzo Amez Navarro
# Guardado: Fernando Rincón Jaramillo
# Guardado: Fernando Rincón Bazo
# Procesando miembros de Familia Antúnez...
# Guardado: Gabino Uribe
# Guardado: Santiago Antúnez de Mayolo
# Guardado: Santiago Antúnez de Mayolo Rynning
# Guardado: Santiago Antúnez de Mayolo Rynning
# Guardado: Santiago Antúnez de Mayolo
# Guardado: Lucie Rynning
# Procesando miembros de Familia Araníbar...
# Guardado: José de Araníbar
# Guardado: Nicolás de Araníbar
# Guardado: José de Araníbar
# Procesando miembros de Familia Aramburú...
# Guardado: Fernando Montero Aramburú
# Guardado: José Félix Aramburú Salinas
# Guardado: Ernesto Aramburú Menchaca
# Guardado: Alfredo Aramburú
# Guardado: Andrés Aramburú Sarrio
# Guardado: Andrés Aramburú Salinas
# Guardado: José Félix Aramburú Salinas
# Guardado: Andrés Aramburú Salinas
# Guardado: Andrés Aramburú Menchaca
# Guardado: Ernesto Aramburú Menchaca
# Guardado: Eleuterio Aramburú
# Guardado: Andrés Aramburú Menchaca
# Procesando miembros de Familia Astete...
# Guardado: Manuel Antonio Astete
# Guardado: Alejandro Velasco Astete
# Guardado: Pedro Astete Núñez
# Guardado: José Sabogal Wiesse
# Procesando miembros de Familia Salaverry...
# Guardado: Fernando Cantuarias
# Guardado: Felipe Cantuarias Salaverry
# Guardado: Daniel Salaverry
# Guardado: Felipe Salaverry
# Guardado: Carlos Augusto Salaverry
# Guardado: Felipe Cantuarias Salaverry
# Guardado: Fernando Cantuarias
# Guardado: Carlos Augusto Salaverry
# Guardado: Felipe Salaverry
# Procesando miembros de Familia Salazar y Meléndez...
# Guardado: Alfredo Salazar Southwell
# Guardado: Augusto Salazar Bondy
# Guardado: Sebastián Salazar Bondy
# Guardado: Arturo Salazar Larraín
# Guardado: Federico Salazar
# Procesando miembros de Familia Samanez...
# Guardado: Hugo Neira Samanez
# Guardado: David Samanez Ocampo
# Procesando miembros de Familia Samanez Ocampo...
# Guardado: José Samanez Ocampo
# Guardado: David Samanez Ocampo
# Guardado: David Samanez Ocampo
# Procesando miembros de Familia Sánchez-Concha...
# Guardado: Manuel Piqueras Luna
# Guardado: Manuel Piqueras Cotolí
# Guardado: Jorge Piqueras
# Guardado: Manuel Piqueras Luna
# Procesando miembros de Familia Sancho Dávila...
# Guardado: Sancho Dávila y Daza
# Guardado: José María Sancho Dávila
# Procesando miembros de Familia Santa Cruz...
# Guardado: Nicomedes Santa Cruz
# Guardado: Rafael Santa Cruz (artista)
# Guardado: Diego de Aliaga y Santa Cruz
# Guardado: Juan de Santa Cruz Pachacuti Yamqui Salcamaygua
# Guardado: Juan José de Aliaga y Santa Cruz
# Guardado: Andrés de Santa Cruz
# Guardado: Rafael Santa Cruz (torero)
# Guardado: Victoria Santa Cruz
# Procesando miembros de Familia Schreiber...
# Guardado: Germán Schreiber
# Guardado: Diómedes Arias Schreiber
# Guardado: Alois Schreiber
# Guardado: Germán Schreiber
# Guardado: Carlos Tubino
# Guardado: Max Arias-Schreiber Pezet
# Guardado: Ricardo Rivera Schreiber
# Procesando miembros de Familia Seminario...
# Guardado: Augusto Seminario y Váscones
# Guardado: Manuel Seminario y Váscones
# Guardado: Miguel Gerónimo Seminario y Jaime
# Guardado: Manuel Seminario y Váscones
# Guardado: Augusto Seminario y Váscones
# Guardado: Fernando Seminario y Echandía
# Guardado: Pablo Seminario y Echandía
# Guardado: Ricardo Seminario y Aramburú
# Guardado: Oswaldo Seminario y Aramburú
# Guardado: Ricardo Seminario y Aramburú
# Guardado: Juan Ignacio Seminario y Echeandía
# Guardado: Pablo Seminario y Echandía
# Guardado: Francisco García y León
# Guardado: Ignacio García y León
# Guardado: Manuel Seminario y Váscones
# Guardado: Oswaldo Seminario y Aramburú
# Guardado: Miguel Grau
# Procesando miembros de Familia Seoane Heredia...
# Guardado: Manuel Burga Seoane
# Guardado: Enrique Seoane Ros
# Guardado: Buenaventura Seoane
# Guardado: Juan Seoane
# Guardado: Manuel Seoane (político)
# Guardado: Edgardo Seoane
# Guardado: Manuel Seoane (político)
# Guardado: Juan Seoane
# Guardado: Guillermo Seoane
# Guardado: Guillermo Seoane
# Guardado: Juan Seoane
# Guardado: Manuel Seoane (político)
# Guardado: Edgardo Seoane
