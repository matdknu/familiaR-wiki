# %%
import requests
from bs4 import BeautifulSoup
import time
import csv

# %%
BASE_URL = "https://es.wikipedia.org"
processed_urls = set()

# %%
def obtener_sopa(url, intentos=3):
    """Realiza una solicitud HTTP y devuelve una BeautifulSoup, con reintentos."""
    for intento in range(intentos):
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            return BeautifulSoup(response.text, 'html.parser')
        except requests.exceptions.Timeout:
            print(f"Tiempo de espera agotado para {url}. Reintentando ({intento + 1}/{intentos})...")
            time.sleep(5)
        except requests.RequestException as e:
            print(f"Error al acceder a {url}: {e}")
            return None
    return None


def extraer_familias(sopa):
    """Extrae las familias desde la página principal de categoría."""
    familias = []
    for div in sopa.find_all('div', class_='mw-category-group'):
        for li in div.find_all('li'):
            a_tag = li.find('a')
            if a_tag and 'Familia' in a_tag.text and 'Fundadoras' not in a_tag.text:
                familias.append((a_tag.text.strip(), BASE_URL + a_tag['href']))
    return familias


def extraer_miembros_familia(sopa):
    """
    Extrae recursivamente los miembros de una categoría:
      1) Recorre subcategorías y llama recursivo.
      2) Luego extrae las páginas de 'mw-pages'.
    """
    miembros = set()
    subcat = sopa.find('div', id='mw-subcategories')
    if subcat:
        for div in subcat.find_all('div', class_='mw-category-group'):
            for li in div.find_all('li'):
                a = li.find('a', href=True)
                if a and '/wiki/Categor%C3%ADa:' in a['href']:
                    sub_sopa = obtener_sopa(BASE_URL + a['href'])
                    if sub_sopa:
                        miembros |= extraer_miembros_familia(sub_sopa)
    pages = sopa.find('div', id='mw-pages')
    if pages:
        for div in pages.find_all('div', class_='mw-category-group'):
            for li in div.find_all('li'):
                a = li.find('a', href=True)
                if a:
                    miembros.add((a.text.strip(), BASE_URL + a['href']))
    return miembros


def save_to_csv(info, filename="familias_argentinas2.csv"):
    """Guarda un diccionario en el CSV si su URL no se ha procesado aún."""
    if info["URL"] in processed_urls:
        return
    processed_urls.add(info["URL"])

    with open(filename, mode='a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        row = [
            info.get("Nombre", ""),
            info.get("Fecha de nacimiento", ""),
            info.get("Residencia", ""),
            info.get("Nacionalidad", ""),
            info.get("Cargos", ""),
            info.get("Educación", ""),
            info.get("Trabajos previos", ""),
            info.get("Área", ""),
            info.get("Partido político", ""),
            info.get("Familia", ""),
            info.get("Categorías", ""),
            info.get("URL", "")
        ]
        writer.writerow(row)


def dedup_csv(filename="familias_argentinas2.csv"):
    """Elimina filas duplicadas en el CSV, basándose en todas las columnas."""
    seen = set()
    unique = []
    with open(filename, newline='', encoding='utf-8') as f:
        reader = csv.reader(f, delimiter=';')
        header = next(reader)
        for row in reader:
            row_tup = tuple(row)
            if row_tup not in seen:
                seen.add(row_tup)
                unique.append(row)
    with open(filename, mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        writer.writerow(header)
        writer.writerows(unique)


def extract_info(url, depth=0, max_depth=1):
    sopa = obtener_sopa(url)
    if not sopa:
        return

    infobox = sopa.find("table", class_="infobox biography vcard")
    if not infobox:
        return

    info = {
        "Nombre": "", "Fecha de nacimiento": "", "Residencia": "",
        "Nacionalidad": "", "Cargos": "", "Educación": "",
        "Trabajos previos": "", "Área": "", "Partido político": "",
        "Familia": "", "Categorías": "", "URL": url
    }

    h1 = sopa.find("h1", class_="firstHeading")
    if h1:
        info["Nombre"] = h1.text.strip()

    cat_div = sopa.find("div", id="mw-normal-catlinks")
    if cat_div:
        info["Categorías"] = "; ".join(a.text for a in cat_div.find_all("a"))

    rows = infobox.find_all("tr")
    for row in rows:
        th = row.find("th")
        td = row.find("td")
        if not th or not td:
            continue
        h = th.text.strip()
        txt = td.get_text(" ", strip=True)

        if "Nacimiento" in h:
            info["Fecha de nacimiento"] = txt
        elif "Residencia" in h:
            info["Residencia"] = txt
        elif "Nacionalidad" in h:
            info["Nacionalidad"] = txt
        elif any(k in h for k in ["Ocupación", "Cargo", "Cargos"]):
            info["Cargos"] = "; ".join(td.stripped_strings)
        elif any(k in h for k in ["Educación", "Educado en", "Educada en"]):
            info["Educación"] = "; ".join(
                a.text for a in td.find_all("a", href=True) if a["href"].startswith("/wiki/")
            )
        elif "Área" in h:
            info["Área"] = txt
        elif "Partido político" in h:
            info["Partido político"] = "; ".join(a.text for a in td.find_all("a", href=True))
        elif any(k in h for k in ["Padres", "Cónyuge", "Hijos", "Familia"]):
            familia = []
            for a in td.find_all("a", href=True):
                href = a["href"]
                if href.startswith("/wiki/") and not any(href.startswith(excl) for excl in [
                        "/wiki/Ayuda:", "/wiki/Archivo:", "/wiki/Especial:",
                        "/wiki/Plantilla:", "/wiki/Portal:", "/wiki/Categor%C3%ADa:", "/wiki/Familia_"
                ]):
                    familia.append(f"{a.text} ({BASE_URL}{href})")
            info["Familia"] = "; ".join(familia)

    for i in range(len(rows)-1):
        th = rows[i].find("th")
        td = rows[i+1].find("td")
        if th and td and th.get("colspan") == "3" and "background-color:#E6E6FA" in th.get("style", ""):
            cargos = "; ".join(a.text for a in th.find_all("a", href=True))
            fechas = td.get_text(" ", strip=True)
            info["Trabajos previos"] += f"{cargos} – {fechas}; "

    save_to_csv(info)
    print(f"Guardado: {info['Nombre']}")

    if depth < max_depth and info["Familia"]:
        for miembro in info["Familia"].split("; "):
            if "(" in miembro and miembro.endswith(")"):
                member_url = miembro.split("(")[1][:-1]
                extract_info(member_url, depth+1, max_depth)
                time.sleep(2)

# %%
def main():
    url_categorias = f'{BASE_URL}/wiki/Categoría:Familias_de_Argentina'

    # Crear CSV con encabezado
    header = [
        "Nombre", "Fecha de nacimiento", "Residencia", "Nacionalidad",
        "Cargos", "Educación", "Trabajos previos", "Área",
        "Partido político", "Familia", "Categorías", "URL"
    ]
    with open("familias_argentinas2.csv", mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        writer.writerow(header)

    sopa_principal = obtener_sopa(url_categorias)
    if not sopa_principal:
        print("No se pudo cargar la categoría principal.")
        return

    familias = extraer_familias(sopa_principal)
    for fam_nombre, fam_url in familias:
        print(f"Procesando miembros de {fam_nombre}...")
        sopa_fam = obtener_sopa(fam_url)
        if not sopa_fam:
            continue
        miembros = extraer_miembros_familia(sopa_fam)
        for _, miembro_url in miembros:
            extract_info(miembro_url, depth=0, max_depth=1)
            time.sleep(1)

    # Eliminar duplicados finales
    dedup_csv("familias_argentinas2.csv")
    print("Extracción completa. CSV limpio y sin duplicados listo.")

if __name__ == '__main__':
    main()
# Out:
# Procesando miembros de Familia Acuña (Argentina)...
# Guardado: Arturo Acuña Anzorena
# Guardado: Pedro Ignacio de Acuña
# Guardado: Pío Isaac Acuña
# Guardado: Tadeo Acuña
# Guardado: Tadeo Acuña
# Guardado: Eusebio Gregorio Ruzo
# Guardado: Pío Isaac Acuña
# Guardado: Tadeo Acuña
# Guardado: Pedro Ignacio Acuña
# Guardado: Rodolfo Acuña
# Guardado: Julio P. Acuña
# Guardado: Joaquín Acuña
# Procesando miembros de Familia Alemann...
# Guardado: Ernesto Alemann
# Guardado: Katja Alemann
# Guardado: Katja Alemann
# Guardado: Juan Alemann
# Guardado: Marie Louise Alemann
# Guardado: Katja Alemann
# Guardado: Roberto Alemann
# Procesando miembros de Familia Allende (Argentina)...
# Guardado: Tomás de Allende
# Guardado: Santiago Allende
# Guardado: Pedro Lucas de Allende
# Guardado: Tomás de Allende
# Guardado: Faustino Allende
# Guardado: Saturnino Allende
# Guardado: Faustino Allende
# Procesando miembros de Familia Alpoim...
# Guardado: Manuel Cabral de Melo y Alpoin
# Guardado: Amador Vaz de Alpoim
# Guardado: Manuel Maciel y Cabral de Alpoin
# Procesando miembros de Familia Álvarez de Arenales...
# Guardado: Juan Antonio Álvarez de Arenales
# Guardado: María Josefa Álvarez de Arenales
# Guardado: Napoleón Uriburu
# Guardado: Evaristo de Uriburu
# Guardado: María Josefa Álvarez de Arenales
# Guardado: María Josefa Álvarez de Arenales
# Guardado: José Evaristo Uriburu
# Guardado: Napoleón Uriburu
# Guardado: José Félix Uriburu
# Guardado: José Evaristo Uriburu
# Guardado: José Evaristo Uriburu
# Guardado: José Félix Uriburu
# Guardado: José María Todd
# Guardado: José Ildefonso Álvarez de Arenales
# Guardado: Evaristo de Uriburu
# Guardado: José Evaristo Uriburu
# Guardado: Napoleón Uriburu
# Procesando miembros de Familia Álvarez de Toledo (Argentina)...
# Guardado: Federico Álvarez de Toledo Bedoya
# Guardado: José María Álvarez de Toledo
# Guardado: Matilde Díaz Vélez
# Guardado: Carlos Díaz Vélez
# Guardado: Federico Álvarez de Toledo
# Guardado: Esmeralda Mitre
# Guardado: Darío Lopérfido
# Procesando miembros de Familia Alvear...
# Guardado: Regina Pacini
# Guardado: Carlos María de Alvear
# Guardado: Emilio de Alvear
# Guardado: Torcuato de Alvear
# Guardado: Carlos Torcuato de Alvear
# Guardado: Marcelo Torcuato de Alvear
# Guardado: Francisco de Alvear y Gómez de la Cortina
# Guardado: Marcelo Torcuato de Alvear
# Guardado: Carlos Torcuato de Alvear
# Guardado: Esteban Bullrich
# Guardado: Emilio de Alvear
# Guardado: Diego de Alvear (nieto)
# Guardado: Carmen de la Quintanilla
# Guardado: Torcuato de Alvear
# Guardado: Torcuato de Alvear
# Guardado: Carlos Torcuato de Alvear
# Guardado: Marcelo Torcuato de Alvear
# Guardado: Vicente P. Peralta
# Guardado: Sabina de Alvear y Ward
# Guardado: Emilio Ocampo
# Guardado: Diego de Alvear y Ponce de León
# Procesando miembros de Familia Álzaga...
# Guardado: Josef de Urquiza
# Guardado: Cipriano de Urquiza
# Guardado: Justo José de Urquiza
# Guardado: José Gregorio de Lezama
# Guardado: Salustiano Lezama
# Guardado: Martín de Álzaga
# Guardado: Justo José de Urquiza
# Guardado: Dolores Costa
# Guardado: Felicitas Guerrero
# Guardado: Félix de Álzaga
# Guardado: Cecilio de Álzaga
# Guardado: Martín de Alzaga Unzué
# Procesando miembros de Familia Ameghino...
# Guardado: Florentino Ameghino
# Guardado: Carlos Ameghino
# Guardado: César Ameghino
# Procesando miembros de Familia Anchorena...
# Guardado: Aarón de Anchorena
# Guardado: Tomás S. de Anchorena
# Guardado: Joaquín Samuel de Anchorena
# Guardado: Tomás Joaquín de Anchorena
# Guardado: Tomás Joaquín de Anchorena
# Guardado: Benito Alberto Nazar Anchorena
# Guardado: Tomás de Anchorena
# Guardado: Manuel de Anchorena
# Guardado: Nicolás Anchorena
# Guardado: Victoria Aguirre Anchorena
# Procesando miembros de Familia Anzoátegui...
# Guardado: Gabino Anzoátegui
# Guardado: Laureano de Anzoátegui
# Guardado: José Dámaso Anzoátegui
# Guardado: Carlos Anzoátegui
# Guardado: Bernardo Joaquín de Anzoátegui
# Guardado: Carlos Anzoátegui
# Procesando miembros de Familia Aráoz...
# Guardado: José Ignacio Helguero
# Guardado: Diego Aráoz
# Guardado: Miguel Mario Campero
# Guardado: Daniel Aráoz (gobernador)
# Guardado: Ántero Flores-Aráoz
# Guardado: Juan Bautista Alberdi
# Guardado: Miguel Aráoz y Arce
# Guardado: Juan Crisóstomo Álvarez
# Guardado: Eudoro Aráoz
# Guardado: Mercedes Aráoz
# Guardado: Gregorio Aráoz de Lamadrid
# Guardado: Bernabé Aráoz
# Guardado: Francisco Aráoz de Lamadrid
# Guardado: Salvador Alberdi
# Guardado: Juan Bautista Alberdi
# Guardado: Benjamín Aráoz
# Guardado: Pedro Miguel Aráoz
# Procesando miembros de Familia Augier...
# Guardado: Vicente Augier
# Guardado: Marcelino Augier
# Guardado: Uladislao Augier
# Guardado: Francisco Rafael Augier
# Procesando miembros de Familia Awada...
# Guardado: Juliana Awada
# Guardado: Alejandro Awada
# Procesando miembros de Familia Azcuénaga...
# Guardado: Vicente de Azcuénaga
# Guardado: Miguel de Azcuénaga
# Guardado: Flora Azcuénaga
# Guardado: Domingo de Azcuénaga y Basavilbaso
# Guardado: Ana de Azcuénaga de Olaguer Feliú
# Guardado: José Benito de Azcuénaga
# Guardado: Domingo de Azcuénaga y Basavilbaso
# Guardado: Clara Isabel Núñez y Chabarria
# Guardado: Domingo de Azcuénaga y Basavilbaso
# Guardado: José Benito de Azcuénaga
# Guardado: Manuel Olaguer Feliú y Azcuénaga
# Guardado: Ana de Azcuénaga de Olaguer Feliú
# Guardado: Antonio Olaguer Feliú
# Guardado: Ana de Azcuénaga de Olaguer Feliú
# Guardado: José Olaguer Feliú y Azcuénaga
# Guardado: Manuel Olaguer Feliú y Azcuénaga
# Guardado: Miguel de Azcuénaga
# Guardado: José Olaguer Feliú y Azcuénaga
# Guardado: Juan José Feliciano Fernández Campero
# Guardado: Fernando María Campero Barragán
# Procesando miembros de Familia Canaveris...
# Guardado: Cornelio Casablanca
# Guardado: Tomás Canavery
# Guardado: Juan de Canaveris
# Guardado: Baldomero Lamela (hijo)
# Guardado: Mariano Canaveris
# Guardado: Eliseo Canaveri
# Guardado: Ángel Canavery
# Procesando miembros de Familia Candioti...
# Guardado: Agustín de Escalada Iriondo
# Guardado: Celedonio Escalada
# Guardado: Urbano de Iriondo
# Guardado: Francisco Candioti
# Guardado: Luis Marcelo Zelarayán
# Guardado: Jorge Martínez Zuviría
# Error al acceder a hijo): Invalid URL 'hijo)': No scheme supplied. Perhaps you meant https://hijo)?
# Guardado: Simón de Iriondo
# Guardado: Simón de Iriondo
# Guardado: Urbano de Iriondo
# Guardado: Agustín de Iriondo Candioti
# Guardado: Simón de Iriondo
# Guardado: Francisco Candioti
# Guardado: Alberto María Candioti
# Guardado: Antonio Candioti y Mujica
# Guardado: Francisco Candioti
# Guardado: Enrique Candioti
# Guardado: Prócoro Crespo
# Guardado: Agustín de Iriondo Candioti
# Guardado: Francisco Candioti
# Guardado: Simón de Iriondo
# Guardado: Miguel Escalada
# Guardado: Hugo Wast
# Guardado: Gustavo Martínez Zuviría (hijo)
# Guardado: Manuel María de Iriondo
# Guardado: Mariano Candioti
# Guardado: Jorge Martínez Zuviría
# Procesando miembros de Familia Cantilo...
# Guardado: Alberto Gelly Cantilo
# Guardado: José María Cantilo
# Guardado: José María Cantilo (nieto)
# Procesando miembros de Familia Cantoni-Bravo...
# Guardado: Leopoldo Alfredo Bravo
# Guardado: Leopoldo Bravo
# Guardado: Leopoldo Alfredo Bravo
# Guardado: Federico Saturnino Bravo
# Guardado: Federico Cantoni
# Guardado: Aldo Cantoni
# Procesando miembros de Familia Castelli...
# Guardado: Juan José Castelli
# Guardado: Pedro Castelli
# Guardado: Ángela Castelli
# Guardado: Pedro Castelli
# Procesando miembros de Familia Coni...
# Guardado: Gabriela Laperrière
# Guardado: Emilio Ángel Coni
# Guardado: Emilio R. Coni
# Procesando miembros de Familia Cortés de Monroy...
# Guardado: Federico Varela Cortés de Monroy
# Guardado: Agustín de Rojas y Cortés Monroy
# Guardado: Fernando de la Fuente y Rojas
# Guardado: Francisco de Aguirre Cortés Monroy
# Guardado: Pedro de la Fuente y Rojas
# Procesando miembros de Familia Cullen...
# Guardado: Tomás Cullen
# Guardado: José María Cullen
# Guardado: Domingo Cullen
# Guardado: Patricio Cullen
# Procesando miembros de Familia de la Rúa...
# Guardado: Antonio de la Rúa (político)
# Guardado: Fernando de la Rúa
# Guardado: Jorge de la Rúa
# Guardado: Fernando de la Rúa
# Guardado: Antonio de la Rúa
# Guardado: Inés Pertiné
# Guardado: Basilio Pertiné
# Guardado: Ignacio Darío Irigoyen
# Guardado: Antonio de la Rúa
# Guardado: Fernando de la Rúa
# Guardado: Inés Pertiné
# Guardado: Jorge de la Rúa
# Procesando miembros de Familia del Carril...
# Guardado: José María del Carril
# Guardado: Salvador María del Carril
# Guardado: José María del Carril
# Guardado: Bonifacio del Carril
# Guardado: Ricardo Güiraldes
# Guardado: Delia del Carril
# Guardado: Pablo Neruda
# Guardado: Tita Tamames
# Procesando miembros de Familia Di Palma...
# Guardado: Marcos Di Palma
# Guardado: Familia Di Palma
# Procesando miembros de Familia Di Tella...
# Guardado: Torcuato Di Tella
# Error al acceder a hijo): Invalid URL 'hijo)': No scheme supplied. Perhaps you meant https://hijo)?
# Guardado: Guido Di Tella
# Guardado: Torcuato Alfredo Sozio Di Tella
# Guardado: Torcuato Di Tella (hijo)
# Guardado: Andrés Di Tella
# Guardado: Guido Di Tella
# Procesando miembros de Familia Díaz Vélez...
# Guardado: Eustoquio Díaz Vélez (hijo)
# Guardado: Carlos Díaz Vélez
# Guardado: Eustoquio Díaz Vélez
# Guardado: Eustoquio Díaz Vélez
# Guardado: Matilde Díaz Vélez
# Guardado: Carlos Díaz Vélez
# Guardado: Manuel Díaz Vélez
# Guardado: Ciriaco Díaz Vélez
# Guardado: Gregorio Aráoz de Lamadrid
# Guardado: Carlos Díaz Vélez
# Guardado: Matilde Díaz Vélez
# Guardado: José Miguel Díaz Vélez
# Guardado: Ciriaco Díaz Vélez
# Procesando miembros de Familia Echagüe...
# Guardado: Pedro Antonio Echagüe
# Guardado: Francisco Xavier de Echagüe
# Procesando miembros de Familia Escalada...
# Guardado: Daniel Domingo de Escalada
# Guardado: Mariano Escalada
# Guardado: Daniel Domingo de Escalada
# Guardado: María Eugenia de Escalada
# Guardado: Tomasa de la Quintana
# Guardado: Manuel Escalada
# Guardado: María de las Nieves de Escalada
# Guardado: María de los Remedios de Escalada
# Guardado: Mariano Escalada
# Guardado: María de las Nieves de Escalada
# Guardado: Mercedes Tomasa San Martín y Escalada
# Guardado: Antonio José de Escalada
# Guardado: Tomasa de la Quintana
# Guardado: Juan de San Martín
# Guardado: Gregoria Matorras
# Guardado: Juan Fermín de San Martín
# Guardado: Francisco Antonio de Escalada
# Guardado: Antonio José de Escalada
# Guardado: María Eugenia de Escalada
# Guardado: Manuel Escalada
# Guardado: María de las Nieves de Escalada
# Guardado: María de los Remedios de Escalada
# Guardado: Mariano Escalada
# Guardado: María de los Remedios de Escalada
# Guardado: Mercedes Tomasa San Martín y Escalada
# Procesando miembros de Familia Escalada (de Burgos)...
# Guardado: Miguel Escalada
# Guardado: Agustín de Escalada Iriondo
# Guardado: Celedonio Escalada
# Guardado: Urbano de Iriondo
# Guardado: Francisco Candioti
# Guardado: Luis Marcelo Zelarayán
# Guardado: Jorge Martínez Zuviría
# Error al acceder a hijo): Invalid URL 'hijo)': No scheme supplied. Perhaps you meant https://hijo)?
# Guardado: Simón de Iriondo
# Guardado: Marcelino Escalada Baldez
# Guardado: Miguel Escalada
# Guardado: Celedonio Escalada
# Procesando miembros de Familia Falú...
# Guardado: Eduardo Falú
# Guardado: Luis Eduardo Falú
# Guardado: Juan Falú
# Guardado: Ana Falú
# Guardado: Eduardo Falú
# Guardado: Juan Falú
# Guardado: Ana Falú
# Procesando miembros de Familia Fernández Cornejo...
# Guardado: Julio Cornejo
# Guardado: Mariano Pío Cornejo
# Guardado: Carlos Menem Jr.
# Guardado: Eduardo Menem
# Guardado: Munir Menem
# Guardado: Martín Menem
# Guardado: Cecilia Bolocco
# Guardado: Diana Bolocco
# Procesando miembros de Familia Montes de Oca...
# Guardado: Luciano Montes de Oca
# Guardado: Manuel Augusto Montes de Oca
# Guardado: Juan José Montes de Oca (médico)
# Guardado: Hilarión Domingo Moreno Montes de Oca
# Guardado: Lucio Moreno Quintana
# Guardado: Emilio Cárdenas
# Guardado: Leopoldo Montes de Oca
# Guardado: Manuel Augusto Montes de Oca (médico)
# Guardado: Juan José Montes de Oca (médico)
# Procesando miembros de Familia O'Gorman...
# Guardado: Ana Perichon
# Guardado: Tomás O'Gorman
# Guardado: Tomás O'Gorman
# Guardado: Ana Perichon
# Guardado: Enrique O'Gorman
# Guardado: Miguel O'Gorman
# Guardado: Camila O'Gorman
# Guardado: Ladislao Gutiérrez
# Procesando miembros de Familia Obligado...
# Guardado: Erasmo Obligado
# Guardado: Clara Obligado
# Guardado: Pastor Obligado
# Guardado: Pastor S. Obligado
# Guardado: Rafael Obligado
# Guardado: Pastor S. Obligado
# Guardado: Manuel Obligado
# Guardado: Pedro Miguel Obligado
# Procesando miembros de Familia Onassis...
# Guardado: Maria Callas
# Guardado: Álvaro de Miranda Neto
# Guardado: Athina Livanos
# Guardado: Athina Roussel
# Guardado: Athina Roussel
# Guardado: Álvaro de Miranda Neto
# Guardado: Aristóteles Onassis
# Guardado: Christina Onassis
# Guardado: Jacqueline Kennedy Onassis
# Guardado: Caroline Kennedy
# Guardado: John F. Kennedy Jr.
# Guardado: Patrick Bouvier Kennedy
# Guardado: Christina Onassis
# Guardado: Athina Roussel
# Procesando miembros de Familia Ortiz Basualdo...
# Guardado: Magdalena Ruiz Guiñazú
# Guardado: Enrique Udaondo
# Guardado: Juan de Lezica y Torrezuri
# Guardado: Francisco de Segurola
# Guardado: Manuel Ortiz Basualdo
# Guardado: Guillermo Udaondo
# Guardado: Carlos Bonorino Udaondo
# Guardado: Manuel Mujica Lainez
# Guardado: José Luis Cantilo
# Guardado: Francisco de Segurola
# Guardado: Manuel Ortiz Basualdo
# Guardado: Ángel Gallardo
# Guardado: Enrique Ruiz Guiñazú
# Guardado: Magdalena Ruiz Guiñazú
# Guardado: Ángel Gallardo
# Guardado: José Luis Cantilo
# Guardado: Carlos Bonorino Udaondo
# Guardado: Francisco de Segurola
# Guardado: Manuel Ortiz Basualdo
# Guardado: Guillermo Udaondo
# Guardado: Enrique Udaondo
# Guardado: Manuel Ortiz Basualdo
# Guardado: Guillermo Udaondo
# Guardado: Luis Federico Leloir
# Guardado: Enrique José Luis Ruiz Guiñazú
# Guardado: Enrique Ruiz Guiñazú
# Guardado: Magdalena Ruiz Guiñazú
# Procesando miembros de Familia Ortiz de Rozas...
# Guardado: Domingo Ortiz de Rozas y Rodillo
# Guardado: Gervasio Ortiz de Rozas
# Guardado: Soledad Rosas
# Guardado: Mercedes Ortiz de Rozas
# Guardado: Juan Manuel de Rosas
# Guardado: Gervasio Ortiz de Rozas
# Guardado: Prudencio Rosas
# Guardado: Agustina Ortiz de Rozas
# Guardado: Juan Lavalle
# Guardado: Manuel Domingo Sánchez de Bustamante
# Procesando miembros de Familia Sabattini...
# Guardado: Amadeo Sabattini
# Guardado: Rosa Clotilde Sabattini
# Guardado: Jorge Barón Biza
# Guardado: Rosa Clotilde Sabattini
# Guardado: Raúl Barón Biza
# Guardado: Rosa Clotilde Sabattini
# Guardado: Jorge Barón Biza
# Guardado: Raúl Barón Biza
# Guardado: Jorge Barón Biza
# Procesando miembros de Familia Sarsfield...
# Guardado: Dalmacio Vélez Sarsfield
# Guardado: Aurelia Vélez Sársfield
# Guardado: Patrick Sarsfield
# Guardado: Aurelia Vélez Sársfield
# Guardado: Domingo Faustino Sarmiento
# Procesando miembros de Familia Segurola...
# Guardado: Wenceslao Paunero
# Guardado: José María Ramos Mejía
# Guardado: Manuel Ortiz Basualdo
# Guardado: Alfredo Barnechea
# Guardado: Francisco Hermógenes Ramos Mejía
# Guardado: Matías Ramos Mejía
# Guardado: Sebastián de Segurola
# Guardado: Matías Ramos Mejía
# Guardado: Sebastián de Segurola
# Guardado: José Ballivián
# Guardado: Juan Lavalle
# Guardado: Francisco Bernabé Madero
# Guardado: Saturnino Segurola
# Guardado: Francisco de Segurola
# Guardado: Sebastián de Segurola
# Guardado: Saturnino Segurola
# Guardado: Juan de Lezica y Torrezuri
# Guardado: Manuel Ortiz Basualdo
# Guardado: Francisco Bernabé Madero
# Procesando miembros de Familia Sieburger...
# Procesando miembros de Familia Simeone...
# Procesando miembros de Familia Snopek...
# Guardado: Guillermo Eugenio Snopek
# Guardado: Guillermo Snopek
# Guardado: Gerardo Morales
# Guardado: Guillermo Snopek (padre)
# Guardado: Guillermo Eugenio Snopek
# Guardado: Guillermo Snopek
# Guardado: Guillermo Eugenio Snopek
# Guardado: Carlos Snopek
# Guardado: Alejandro Snopek
# Procesando miembros de Familia Solari (Argentina)...
# Guardado: Liz Solari
# Procesando miembros de Familia Taboada...
# Guardado: Antonino Taboada
# Guardado: Felipe Taboada
# Guardado: Manuel Taboada
# Guardado: Francisco Gil de Taboada
# Procesando miembros de Familia Urtubey...
# Guardado: Juan Manuel Urtubey
# Guardado: Julio Mera Figueroa
# Guardado: Rodolfo Urtubey
# Guardado: Alejandro Urtubey
# Guardado: Dalmacio Mera Figueroa
# Guardado: Alejandro Urtubey
# Guardado: Clodomiro Urtubey
# Guardado: Isabel Macedo
# Guardado: Rodolfo Urtubey
# Procesando miembros de Familia Vaca Narvaja...
# Guardado: Hugo Vaca Narvaja
# Guardado: Fernando Vaca Narvaja
# Guardado: Patricia Vaca Narvaja
# Guardado: Patricia Vaca Narvaja
# Guardado: Fernando Vaca Narvaja
# Guardado: Fernando Vaca Narvaja
# Guardado: Patricia Vaca Narvaja
# Procesando miembros de Familia Varela...
# Guardado: Horacio Beccar Varela
# Guardado: Florencio Varela (escritor)
# Guardado: Luis Vicente Varela
# Guardado: Manuel Augusto Montes de Oca
# Guardado: José Pedro Varela
# Guardado: Jacobo Varela
# Guardado: Luis Vicente Varela
# Guardado: Luis Varela y Orbegoso
# Guardado: Enrique Varela Vidaurre
