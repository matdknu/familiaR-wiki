# %%
import requests
from bs4 import BeautifulSoup
import time
import csv

# %%
BASE_URL = "https://es.wikipedia.org"
processed_urls = set()

# %%
def obtener_sopa(url, intentos=3):
    """Realiza una solicitud HTTP y devuelve una BeautifulSoup, con reintentos."""
    for intento in range(intentos):
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            return BeautifulSoup(response.text, 'html.parser')
        except requests.exceptions.Timeout:
            print(f"Tiempo de espera agotado para {url}. Reintentando ({intento + 1}/{intentos})...")
            time.sleep(5)
        except requests.RequestException as e:
            print(f"Error al acceder a {url}: {e}")
            return None
    return None


def extraer_familias(sopa):
    """Extrae las familias desde la página principal de categoría."""
    familias = []
    for div in sopa.find_all('div', class_='mw-category-group'):
        for li in div.find_all('li'):
            a_tag = li.find('a')
            if a_tag and 'Familia' in a_tag.text and 'Fundadoras' not in a_tag.text:
                familias.append((a_tag.text.strip(), BASE_URL + a_tag['href']))
    return familias


def extraer_miembros_familia(sopa):
    """
    Extrae recursivamente los miembros de una categoría:
      1) Recorre subcategorías y llama recursivo.
      2) Luego extrae las páginas de 'mw-pages'.
    """
    miembros = set()
    subcat = sopa.find('div', id='mw-subcategories')
    if subcat:
        for div in subcat.find_all('div', class_='mw-category-group'):
            for li in div.find_all('li'):
                a = li.find('a', href=True)
                if a and '/wiki/Categor%C3%ADa:' in a['href']:
                    sub_sopa = obtener_sopa(BASE_URL + a['href'])
                    if sub_sopa:
                        miembros |= extraer_miembros_familia(sub_sopa)
    pages = sopa.find('div', id='mw-pages')
    if pages:
        for div in pages.find_all('div', class_='mw-category-group'):
            for li in div.find_all('li'):
                a = li.find('a', href=True)
                if a:
                    miembros.add((a.text.strip(), BASE_URL + a['href']))
    return miembros


def save_to_csv(info, filename="familias_venezolana.csv"):
    """Guarda un diccionario en el CSV si su URL no se ha procesado aún."""
    if info["URL"] in processed_urls:
        return
    processed_urls.add(info["URL"])

    with open(filename, mode='a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        row = [
            info.get("Nombre", ""),
            info.get("Fecha de nacimiento", ""),
            info.get("Residencia", ""),
            info.get("Nacionalidad", ""),
            info.get("Cargos", ""),
            info.get("Educación", ""),
            info.get("Trabajos previos", ""),
            info.get("Área", ""),
            info.get("Partido político", ""),
            info.get("Familia", ""),
            info.get("Categorías", ""),
            info.get("URL", "")
        ]
        writer.writerow(row)


def dedup_csv(filename="familias_venezolanas.csv"):
    """Elimina filas duplicadas en el CSV, basándose en todas las columnas."""
    seen = set()
    unique = []
    with open(filename, newline='', encoding='utf-8') as f:
        reader = csv.reader(f, delimiter=';')
        header = next(reader)
        for row in reader:
            row_tup = tuple(row)
            if row_tup not in seen:
                seen.add(row_tup)
                unique.append(row)
    with open(filename, mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        writer.writerow(header)
        writer.writerows(unique)


def extract_info(url, depth=0, max_depth=1):
    sopa = obtener_sopa(url)
    if not sopa:
        return

    infobox = sopa.find("table", class_="infobox biography vcard")
    if not infobox:
        return

    info = {
        "Nombre": "", "Fecha de nacimiento": "", "Residencia": "",
        "Nacionalidad": "", "Cargos": "", "Educación": "",
        "Trabajos previos": "", "Área": "", "Partido político": "",
        "Familia": "", "Categorías": "", "URL": url
    }

    h1 = sopa.find("h1", class_="firstHeading")
    if h1:
        info["Nombre"] = h1.text.strip()

    cat_div = sopa.find("div", id="mw-normal-catlinks")
    if cat_div:
        info["Categorías"] = "; ".join(a.text for a in cat_div.find_all("a"))

    rows = infobox.find_all("tr")
    for row in rows:
        th = row.find("th")
        td = row.find("td")
        if not th or not td:
            continue
        h = th.text.strip()
        txt = td.get_text(" ", strip=True)

        if "Nacimiento" in h:
            info["Fecha de nacimiento"] = txt
        elif "Residencia" in h:
            info["Residencia"] = txt
        elif "Nacionalidad" in h:
            info["Nacionalidad"] = txt
        elif any(k in h for k in ["Ocupación", "Cargo", "Cargos"]):
            info["Cargos"] = "; ".join(td.stripped_strings)
        elif any(k in h for k in ["Educación", "Educado en", "Educada en"]):
            info["Educación"] = "; ".join(
                a.text for a in td.find_all("a", href=True) if a["href"].startswith("/wiki/")
            )
        elif "Área" in h:
            info["Área"] = txt
        elif "Partido político" in h:
            info["Partido político"] = "; ".join(a.text for a in td.find_all("a", href=True))
        elif any(k in h for k in ["Padres", "Cónyuge", "Hijos", "Familia"]):
            familia = []
            for a in td.find_all("a", href=True):
                href = a["href"]
                if href.startswith("/wiki/") and not any(href.startswith(excl) for excl in [
                        "/wiki/Ayuda:", "/wiki/Archivo:", "/wiki/Especial:",
                        "/wiki/Plantilla:", "/wiki/Portal:", "/wiki/Categor%C3%ADa:", "/wiki/Familia_"
                ]):
                    familia.append(f"{a.text} ({BASE_URL}{href})")
            info["Familia"] = "; ".join(familia)

    for i in range(len(rows)-1):
        th = rows[i].find("th")
        td = rows[i+1].find("td")
        if th and td and th.get("colspan") == "3" and "background-color:#E6E6FA" in th.get("style", ""):
            cargos = "; ".join(a.text for a in th.find_all("a", href=True))
            fechas = td.get_text(" ", strip=True)
            info["Trabajos previos"] += f"{cargos} – {fechas}; "

    save_to_csv(info)
    print(f"Guardado: {info['Nombre']}")

    if depth < max_depth and info["Familia"]:
        for miembro in info["Familia"].split("; "):
            if "(" in miembro and miembro.endswith(")"):
                member_url = miembro.split("(")[1][:-1]
                extract_info(member_url, depth+1, max_depth)
                time.sleep(2)

# %%
def main():
    url_categorias = f'{BASE_URL}/wiki/Categoría:Familias_de_Venezuela'

    # Crear CSV con encabezado
    header = [
        "Nombre", "Fecha de nacimiento", "Residencia", "Nacionalidad",
        "Cargos", "Educación", "Trabajos previos", "Área",
        "Partido político", "Familia", "Categorías", "URL"
    ]
    with open("familias_familias_venezolana.csv", mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        writer.writerow(header)

    sopa_principal = obtener_sopa(url_categorias)
    if not sopa_principal:
        print("No se pudo cargar la categoría principal.")
        return

    familias = extraer_familias(sopa_principal)
    for fam_nombre, fam_url in familias:
        print(f"Procesando miembros de {fam_nombre}...")
        sopa_fam = obtener_sopa(fam_url)
        if not sopa_fam:
            continue
        miembros = extraer_miembros_familia(sopa_fam)
        for _, miembro_url in miembros:
            extract_info(miembro_url, depth=0, max_depth=1)
            time.sleep(1)

    # Eliminar duplicados finales
    dedup_csv("familias_venezolana.csv")
    print("Extracción completa. CSV limpio y sin duplicados listo.")

if __name__ == '__main__':
    main()
# Out:
# Procesando miembros de Familia Boulton (Venezuela)...
# Guardado: Carolina Alfonzo
# Guardado: María Teresa Boulton
# Guardado: Alfredo Boulton
# Guardado: Benigno Filomeno de Rojas
# Guardado: Arístides Rojas
# Guardado: José María Rojas Espaillat
# Guardado: Juan Pietri
# Guardado: Arturo Uslar Pietri
# Guardado: Gustavo Vollmer Herrera
# Guardado: Ulises Espaillat
# Guardado: Alfredo Boulton
# Guardado: Juan Pietri
# Guardado: María Teresa Boulton
# Guardado: Benigno Filomeno de Rojas
# Guardado: Arístides Rojas
# Guardado: José María Rojas Espaillat
# Guardado: Arturo Uslar Pietri
# Guardado: Gustavo Vollmer Herrera
# Guardado: Ulises Espaillat
# Guardado: Eduardo Schlageter
# Guardado: Marena Bencomo
# Procesando miembros de Familia Baduel...
# Guardado: Andreína Baduel
# Guardado: Josnars Baduel
# Guardado: Josnars Baduel
# Guardado: Andreína Baduel
# Guardado: Raúl Isaías Baduel
# Guardado: Josnars Baduel
# Guardado: Andreína Baduel
# Procesando miembros de Familia Blanco (Venezuela)...
# Guardado: Eduardo Blanco (escritor)
# Guardado: Simón Planas
# Guardado: Simón Planas Suárez
# Guardado: María Corina Machado
# Guardado: Antonio Leocadio Guzmán
# Guardado: Antonio Guzmán Blanco
# Guardado: Antonio Guzmán Blanco
# Guardado: César Zumeta
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: Pedro Palacios y Sojo
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: Guillermo Palacios Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Fernando Bolívar
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: César Zumeta
# Guardado: Francisco Rodríguez del Toro
# Guardado: Fernando Rodríguez del Toro
# Guardado: Juan Rodríguez del Toro
# Guardado: Gustavo Vollmer Herrera
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Juan Agustín Bolívar
# Guardado: María Teresa del Toro
# Guardado: José Félix Ribas
# Guardado: Rufino Blanco Fombona
# Guardado: Francisco Rodríguez del Toro
# Guardado: Fernando Rodríguez del Toro
# Guardado: Juan Rodríguez del Toro
# Guardado: Bernardo Herrera
# Guardado: Esteban Herrera Toro
# Guardado: Diego Ibarra
# Guardado: Andrés Horacio Ibarra
# Guardado: María Teresa del Toro
# Guardado: Martín José Sanabria
# Guardado: Antonio Herrera Toro
# Guardado: María Corina Machado
# Guardado: Carlos Toro Manrique
# Guardado: Fermín Toro
# Guardado: Ricardo Zuloaga
# Guardado: Martín Tovar y Tovar
# Guardado: María Corina Machado
# Procesando miembros de Familia Bolívar...
# Guardado: Anacleto Clemente Bolívar
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Feliciano Palacios y Sojo
# Guardado: Pedro Palacios y Sojo
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: Juana Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Juan Agustín Bolívar
# Guardado: Guillermo Palacios Bolívar
# Guardado: Fernando Bolívar
# Guardado: Wenceslao Urrutia
# Guardado: Eugenio Mendoza Goiticoa
# Guardado: Eduardo Mendoza Goiticoa
# Guardado: Antonio Guzmán Blanco
# Guardado: Gustavo Vollmer Herrera
# Guardado: Hipólita Bolívar
# Guardado: Simón Bolívar
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Feliciano Palacios y Sojo
# Guardado: Pedro Palacios y Sojo
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juana Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Juan Agustín Bolívar
# Guardado: Guillermo Palacios Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Eugenio Mendoza Goiticoa
# Guardado: Eduardo Mendoza Goiticoa
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: Gustavo Vollmer Herrera
# Guardado: César Zumeta
# Guardado: María Teresa del Toro
# Guardado: José Laurencio Silva
# Guardado: Juan de la Madriz
# Guardado: María Teresa del Toro
# Guardado: Francisco Rodríguez del Toro e Isturiz
# Guardado: José Rodríguez del Toro
# Guardado: Francisco Rodríguez del Toro
# Guardado: Fernando Rodríguez del Toro
# Guardado: Juan Rodríguez del Toro
# Guardado: Bernardo Herrera
# Guardado: Esteban Herrera Toro
# Guardado: Diego Ibarra
# Guardado: Fermín Toro
# Guardado: Andrés Horacio Ibarra
# Guardado: Martín José Sanabria
# Guardado: Teresa Carreño
# Guardado: Antonio Herrera Toro
# Guardado: Carlos Toro Manrique
# Guardado: Elías Toro
# Guardado: Rufino Blanco Fombona
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: Carlos Acedo Toro
# Guardado: Miguel Toro Ramírez
# Guardado: José Antonio Calcaño
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juana Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Juan Agustín Bolívar
# Guardado: Simón de Bolívar y Castro
# Guardado: Alonso Díaz Moreno
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Simón Bolívar
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Feliciano Palacios y Sojo
# Guardado: Pedro Palacios y Sojo
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juana Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Juan Agustín Bolívar
# Guardado: Guillermo Palacios Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Fernando Bolívar
# Guardado: Eugenio Mendoza Goiticoa
# Guardado: Eduardo Mendoza Goiticoa
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: Gustavo Vollmer Herrera
# Guardado: César Zumeta
# Guardado: Guillermo Palacios Bolívar
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Feliciano Palacios y Sojo
# Guardado: Pedro Palacios y Sojo
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Juan Agustín Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Fernando Bolívar
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: Gustavo Vollmer Herrera
# Guardado: Eugenio Mendoza Goiticoa
# Guardado: Eduardo Mendoza Goiticoa
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Alonso Díaz Moreno
# Guardado: Simón de Bolívar y Castro
# Guardado: Juan Agustín Bolívar
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juana Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Guillermo Palacios Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Fernando Bolívar
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: Juan Agustín Bolívar
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juana Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Guillermo Palacios Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Fernando Bolívar
# Guardado: María Teresa del Toro
# Guardado: Eugenio Mendoza Goiticoa
# Guardado: Eduardo Mendoza Goiticoa
# Guardado: Juana Bolívar Palacios
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Feliciano Palacios y Sojo
# Guardado: Pedro Palacios y Sojo
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Juan Agustín Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Fernando Bolívar
# Guardado: Eugenio Mendoza Goiticoa
# Guardado: Eduardo Mendoza Goiticoa
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: Gustavo Vollmer Herrera
# Guardado: César Zumeta
# Guardado: María Teresa del Toro
# Guardado: Fernando Bolívar
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Feliciano Palacios y Sojo
# Guardado: Pedro Palacios y Sojo
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juana Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Juan Agustín Bolívar
# Guardado: Guillermo Palacios Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: José Laurencio Silva
# Guardado: Wenceslao Urrutia
# Guardado: Eugenio Mendoza Goiticoa
# Guardado: Eduardo Mendoza Goiticoa
# Guardado: Antonio Guzmán Blanco
# Guardado: Gustavo Vollmer Herrera
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Feliciano Palacios y Sojo
# Guardado: Pedro Palacios y Sojo
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: Juana Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Juan Agustín Bolívar
# Guardado: Guillermo Palacios Bolívar
# Guardado: Fernando Bolívar
# Guardado: Eugenio Mendoza Goiticoa
# Guardado: Eduardo Mendoza Goiticoa
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: Gustavo Vollmer Herrera
# Guardado: César Zumeta
# Guardado: María Teresa del Toro
# Guardado: Matea Bolívar
# Procesando miembros de Familia Capriles...
# Guardado: Henrique Capriles
# Guardado: Teodoro Capriles
# Guardado: Carlos Capriles
# Guardado: Miguel Ángel Capriles
# Guardado: Renato Capriles
# Guardado: Gloria Lizárraga de Capriles
# Guardado: Elías Capriles
# Procesando miembros de Familia Cabello...
# Guardado: Glenna Cabello
# Guardado: Diosdado Cabello
# Guardado: Milagros Cabello
# Guardado: José David Cabello
# Guardado: Daniella Cabello
# Guardado: Marleny Contreras
# Guardado: Marleny Contreras
# Guardado: Glenna Cabello
# Guardado: Milagros Cabello
# Guardado: José David Cabello
# Guardado: Omar Acedo
# Guardado: Milagros Cabello
# Guardado: Glenna Cabello
# Guardado: Diosdado Cabello
# Guardado: José David Cabello
# Guardado: Daniella Cabello
# Guardado: Marleny Contreras
# Guardado: Daniella Cabello
# Guardado: Glenna Cabello
# Guardado: Milagros Cabello
# Guardado: José David Cabello
# Guardado: José David Cabello
# Guardado: Glenna Cabello
# Guardado: Diosdado Cabello
# Guardado: Milagros Cabello
# Guardado: Daniella Cabello
# Guardado: Marleny Contreras
# Guardado: Alexis Rodríguez Cabello
# Guardado: Diosdado Cabello
# Guardado: Omar Acedo
# Guardado: Diosdado Cabello
# Guardado: José David Cabello
# Guardado: Glenna Cabello
# Guardado: Milagros Cabello
# Guardado: Alexis Rodríguez Cabello
# Procesando miembros de Familia Portocarrero (Colombia)...
# Guardado: Julio Portocarrero O'Leary
# Guardado: Daniel Florencio O'Leary
# Guardado: Carlos Soublette
# Guardado: José María Portocarrero
# Guardado: Jaime Michelsen Uribe
# Guardado: María Cristina Arango
# Guardado: Andrés Pastrana
# Guardado: Ricardo Portocarrero Caicedo
# Guardado: Jorge Miguel Lozano de Peralta
# Guardado: Luis Caycedo y Flórez
# Guardado: Jorge Tadeo Lozano
# Guardado: Daniel Florencio O'Leary
# Guardado: José María Portocarrero
# Guardado: Jaime Michelsen Uribe
# Guardado: María Cristina Arango
# Guardado: Andrés Pastrana
# Guardado: Simón O'Leary Soublette
# Guardado: Carlos Soublette
# Guardado: Ricardo Portocarrero Caicedo
# Guardado: Mariano Ospina Chaparro
# Guardado: Pastor Ospina Rodríguez
# Guardado: José María Portocarrero
# Guardado: Jorge Miguel Lozano de Peralta
# Guardado: Tadea González Manrique
# Guardado: Jorge Tadeo Lozano
# Guardado: José María Lozano de Peralta
# Guardado: Josefa Lozano y González Manrique
# Guardado: Antonio Ricaurte
# Guardado: José Maria Vergara y Lozano
# Guardado: Tadea Lozano e Isasi
# Guardado: Teresa Lozano e Isasi
# Guardado: Ricardo Portocarrero Caicedo
# Guardado: Julio Portocarrero O'Leary
# Guardado: Juan Carlos Esguerra
# Guardado: Alfonso Esguerra Gómez
# Guardado: Miguel Samper
# Guardado: Nicolás Esguerra
# Guardado: José María Portocarrero
# Guardado: Jorge Miguel Lozano de Peralta
# Procesando miembros de Familia Febres-Cordero...
# Guardado: Antonio Febres-Cordero
# Guardado: Tulio Febres-Cordero
# Guardado: Georgina Febres-Cordero
# Guardado: Georgina Febres-Cordero
# Guardado: Tulio Febres-Cordero
# Guardado: Foción Febres-Cordero
# Guardado: Tulio Febres-Cordero
# Guardado: Georgina Febres-Cordero
# Guardado: Antonio Febres-Cordero
# Procesando miembros de Familia Lander...
# Guardado: Cynthia Lander
# Guardado: Tomás Lander
# Guardado: Domingo Guzmán Lander
# Guardado: Cristóbal Lander
# Guardado: Edgardo Lander
# Guardado: Astrid Lander
# Procesando miembros de Familia López (Venezuela)...
# Guardado: Carlos López Bustamante
# Guardado: Eduardo López Bustamante
# Guardado: Teresa López Bustamante
# Guardado: Enrique López Bustamante
# Guardado: Teresa López Bustamante
# Guardado: Eduardo López Bustamante
# Guardado: Carlos López Bustamante
# Guardado: Enrique López Bustamante
# Guardado: Enrique López Bustamante
# Guardado: Eduardo López Bustamante
# Guardado: Teresa López Bustamante
# Guardado: Carlos López Bustamante
# Guardado: Eduardo López Bustamante
# Guardado: Teresa López Bustamante
# Guardado: Carlos López Bustamante
# Guardado: Enrique López Bustamante
# Guardado: Luis Giusti López
# Guardado: Aurora López Pérez
# Guardado: Eduardo López Bustamante
# Guardado: Eduardo López Rivas
# Guardado: Eduardo López Bustamante
# Guardado: Teresa López Bustamante
# Guardado: Carlos López Bustamante
# Guardado: Enrique López Bustamante
# Procesando miembros de Familia Maduro...
# Guardado: Nicolás Maduro Guerra
# Guardado: Cilia Flores
# Guardado: Nicolás Maduro
# Guardado: Nicolás Maduro Guerra
# Guardado: Cilia Flores
# Guardado: Nicolás Maduro Guerra
# Procesando miembros de Familia Palacios (Venezuela)...
# Guardado: Feliciano Palacios y Sojo
# Guardado: Pedro Palacios y Sojo
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juana Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Guillermo Palacios Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Fernando Bolívar
# Guardado: Wenceslao Urrutia
# Guardado: José Félix Ribas
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Feliciano Palacios y Sojo
# Guardado: Pedro Palacios y Sojo
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juana Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Juan Agustín Bolívar
# Guardado: Guillermo Palacios Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Eugenio Mendoza Goiticoa
# Guardado: Eduardo Mendoza Goiticoa
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: Gustavo Vollmer Herrera
# Guardado: César Zumeta
# Guardado: María Teresa del Toro
# Guardado: José Laurencio Silva
# Guardado: Esteban Palacios y Blanco
# Guardado: Pedro Palacios y Sojo
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: Carlos Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juana Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Guillermo Palacios Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Fernando Bolívar
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: César Zumeta
# Guardado: Francisco Rodríguez del Toro
# Guardado: Fernando Rodríguez del Toro
# Guardado: Juan Rodríguez del Toro
# Guardado: Gustavo Vollmer Herrera
# Guardado: José Félix Ribas
# Guardado: Carlos Palacios y Blanco
# Guardado: Pedro Palacios y Sojo
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juana Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Guillermo Palacios Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Fernando Bolívar
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: César Zumeta
# Guardado: Francisco Rodríguez del Toro
# Guardado: Fernando Rodríguez del Toro
# Guardado: Juan Rodríguez del Toro
# Guardado: Gustavo Vollmer Herrera
# Guardado: José Félix Ribas
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: Pedro Palacios y Sojo
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: Guillermo Palacios Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Fernando Bolívar
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: César Zumeta
# Guardado: Francisco Rodríguez del Toro
# Guardado: Fernando Rodríguez del Toro
# Guardado: Juan Rodríguez del Toro
# Guardado: Gustavo Vollmer Herrera
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Juan Agustín Bolívar
# Guardado: María Teresa del Toro
# Guardado: José Félix Ribas
# Guardado: Simón Bolívar
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Feliciano Palacios y Sojo
# Guardado: Pedro Palacios y Sojo
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juana Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Juan Agustín Bolívar
# Guardado: Guillermo Palacios Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Fernando Bolívar
# Guardado: Eugenio Mendoza Goiticoa
# Guardado: Eduardo Mendoza Goiticoa
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: Gustavo Vollmer Herrera
# Guardado: César Zumeta
# Guardado: Guillermo Palacios Bolívar
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Feliciano Palacios y Sojo
# Guardado: Pedro Palacios y Sojo
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Juan Agustín Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Fernando Bolívar
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: Gustavo Vollmer Herrera
# Guardado: Eugenio Mendoza Goiticoa
# Guardado: Eduardo Mendoza Goiticoa
# Guardado: Mariantonia Palacios
# Guardado: Juan Francisco Sans
# Guardado: Juana Bolívar Palacios
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Feliciano Palacios y Sojo
# Guardado: Pedro Palacios y Sojo
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Juan Agustín Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Fernando Bolívar
# Guardado: Eugenio Mendoza Goiticoa
# Guardado: Eduardo Mendoza Goiticoa
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: Gustavo Vollmer Herrera
# Guardado: César Zumeta
# Guardado: María Teresa del Toro
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Feliciano Palacios y Sojo
# Guardado: Pedro Palacios y Sojo
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: Juana Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Simón Bolívar
# Guardado: Juan Agustín Bolívar
# Guardado: Guillermo Palacios Bolívar
# Guardado: Fernando Bolívar
# Guardado: Eugenio Mendoza Goiticoa
# Guardado: Eduardo Mendoza Goiticoa
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: Gustavo Vollmer Herrera
# Guardado: César Zumeta
# Guardado: María Teresa del Toro
# Procesando miembros de Familia Toro (Venezuela)...
# Guardado: María Teresa del Toro
# Guardado: Francisco Rodríguez del Toro e Isturiz
# Guardado: José Rodríguez del Toro
# Guardado: Francisco Rodríguez del Toro
# Guardado: Fernando Rodríguez del Toro
# Guardado: Juan Rodríguez del Toro
# Guardado: Bernardo Herrera
# Guardado: Esteban Herrera Toro
# Guardado: Diego Ibarra
# Guardado: Fermín Toro
# Guardado: Andrés Horacio Ibarra
# Guardado: Martín José Sanabria
# Guardado: Teresa Carreño
# Guardado: Antonio Herrera Toro
# Guardado: Carlos Toro Manrique
# Guardado: Elías Toro
# Guardado: Rufino Blanco Fombona
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: Carlos Acedo Toro
# Guardado: Miguel Toro Ramírez
# Guardado: José Antonio Calcaño
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juana Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Juan Agustín Bolívar
# Guardado: Simón Bolívar
# Guardado: Juan de Bolívar y Martínez de Villegas
# Guardado: Feliciano Palacios y Sojo
# Guardado: Pedro Palacios y Sojo
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: María Antonia Bolívar Palacios
# Guardado: Juana Bolívar Palacios
# Guardado: Juan Vicente Bolívar Palacios
# Guardado: Juan Agustín Bolívar
# Guardado: Guillermo Palacios Bolívar
# Guardado: Anacleto Clemente Bolívar
# Guardado: Fernando Bolívar
# Guardado: Eugenio Mendoza Goiticoa
# Guardado: Eduardo Mendoza Goiticoa
# Guardado: Wenceslao Urrutia
# Guardado: Antonio Guzmán Blanco
# Guardado: Gustavo Vollmer Herrera
# Guardado: César Zumeta
# Guardado: Rufino Blanco Fombona
# Guardado: Francisco Rodríguez del Toro
# Guardado: Fernando Rodríguez del Toro
# Guardado: Juan Rodríguez del Toro
# Guardado: Bernardo Herrera
# Guardado: Esteban Herrera Toro
# Guardado: Diego Ibarra
# Guardado: Andrés Horacio Ibarra
# Guardado: María Teresa del Toro
# Guardado: Martín José Sanabria
# Guardado: Antonio Herrera Toro
# Guardado: María Corina Machado
# Guardado: Carlos Toro Manrique
# Guardado: Fermín Toro
# Guardado: Carlos Toro Manrique
# Guardado: Miguel Toro Ramírez
# Guardado: José Rodríguez del Toro
# Guardado: Francisco Rodríguez del Toro e Isturiz
# Guardado: Francisco Rodríguez del Toro
# Guardado: Fernando Rodríguez del Toro
# Guardado: Juan Rodríguez del Toro
# Guardado: María Teresa del Toro
# Guardado: Bernardo Herrera
# Guardado: Esteban Herrera Toro
# Guardado: Diego Ibarra
# Guardado: Andrés Horacio Ibarra
# Guardado: Antonio Herrera Toro
# Guardado: Carlos Toro Manrique
# Guardado: Fermín Toro Jiménez
# Guardado: Martín José Sanabria
# Guardado: Francisco Rodríguez del Toro e Isturiz
# Guardado: José Rodríguez del Toro
# Guardado: Francisco Rodríguez del Toro
# Guardado: Fernando Rodríguez del Toro
# Guardado: Juan Rodríguez del Toro
# Guardado: José Antonio Calcaño
# Guardado: Bernardo Herrera
# Guardado: Esteban Herrera Toro
# Guardado: Diego Ibarra
# Guardado: Andrés Horacio Ibarra
# Guardado: María Teresa del Toro
# Guardado: Antonio Herrera Toro
# Guardado: Fermín Toro
# Guardado: Carlos Toro Manrique
# Guardado: Rufino Blanco Fombona
# Guardado: Teresa Carreño
# Guardado: Carlos Acedo Toro
# Guardado: Miguel Toro Ramírez
# Guardado: José Antonio Calcaño
# Guardado: Andrés Ibarra (militar)
# Guardado: José Toro Hardy
# Guardado: Francisco Rodríguez del Toro
# Guardado: Francisco Rodríguez del Toro e Isturiz
# Guardado: José Rodríguez del Toro
# Guardado: Fernando Rodríguez del Toro
# Guardado: Juan Rodríguez del Toro
# Guardado: María Teresa del Toro
# Guardado: Bernardo Herrera
# Guardado: Esteban Herrera Toro
# Guardado: Diego Ibarra
# Guardado: Andrés Horacio Ibarra
# Guardado: Martín José Sanabria
# Guardado: Antonio Herrera Toro
# Guardado: Carlos Toro Manrique
# Guardado: Rufino Blanco Fombona
# Guardado: Carlos Acedo Toro
# Guardado: Miguel Toro Ramírez
# Guardado: José Antonio Calcaño
# Guardado: Fermín Toro
# Guardado: Teresa Carreño
# Guardado: Elías Toro
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: Antonio Herrera Toro
# Guardado: Juan Rodríguez del Toro
# Guardado: Francisco Rodríguez del Toro e Isturiz
# Guardado: José Rodríguez del Toro
# Guardado: Francisco Rodríguez del Toro
# Guardado: Fernando Rodríguez del Toro
# Guardado: María Teresa del Toro
# Guardado: Bernardo Herrera
# Guardado: Esteban Herrera Toro
# Guardado: Diego Ibarra
# Guardado: Andrés Horacio Ibarra
# Guardado: Antonio Herrera Toro
# Guardado: Rufino Blanco Fombona
# Guardado: Carlos Acedo Toro
# Guardado: Miguel Toro Ramírez
# Guardado: José Antonio Calcaño
# Guardado: Fermín Toro
# Guardado: Teresa Carreño
# Guardado: Elías Toro
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: Miguel Toro Ramírez
# Guardado: Eduardo Blanco (escritor)
# Guardado: Simón Planas
# Guardado: Simón Planas Suárez
# Guardado: María Corina Machado
# Guardado: Carlos Acedo Toro
# Guardado: Bernardo Herrera
# Guardado: Fermín Toro
# Guardado: Alfredo Toro Hardy
# Guardado: Esteban Herrera Toro
# Guardado: Elías Toro
# Guardado: Fernando Rodríguez del Toro
# Guardado: Francisco Rodríguez del Toro e Isturiz
# Guardado: José Rodríguez del Toro
# Guardado: Francisco Rodríguez del Toro
# Guardado: Juan Rodríguez del Toro
# Guardado: María Teresa del Toro
# Guardado: Bernardo Herrera
# Guardado: Esteban Herrera Toro
# Guardado: Diego Ibarra
# Guardado: Andrés Horacio Ibarra
# Guardado: Antonio Herrera Toro
# Guardado: Rufino Blanco Fombona
# Guardado: Carlos Acedo Toro
# Guardado: Miguel Toro Ramírez
# Guardado: José Antonio Calcaño
# Guardado: Fermín Toro
# Guardado: Teresa Carreño
# Guardado: Elías Toro
# Guardado: María de la Concepción Palacios y Blanco
# Guardado: Carlos Palacios y Blanco
# Guardado: Esteban Palacios y Blanco
# Guardado: Diego Ibarra
# Guardado: Teresa Carreño
# Guardado: Francisco Rodríguez del Toro e Isturiz
# Guardado: José Rodríguez del Toro
# Guardado: Francisco Rodríguez del Toro
# Guardado: Fernando Rodríguez del Toro
# Guardado: Juan Rodríguez del Toro
# Guardado: María Teresa del Toro
# Guardado: Bernardo Herrera
# Guardado: Esteban Herrera Toro
# Guardado: Diego Ibarra
# Guardado: Andrés Horacio Ibarra
# Guardado: Fermín Toro
# Guardado: Martín José Sanabria
# Guardado: Teresa Carreño
# Guardado: Antonio Herrera Toro
# Procesando miembros de Familia Pinto...
# Procesando miembros de Familia Tezanos Pinto...
# Procesando miembros de Familia Makled...
# Procesando miembros de Familia Primera...
# Procesando miembros de Familia Urdaneta...
# Procesando miembros de Familia Zubillaga (Venezuela)...
# Extracción completa. CSV limpio y sin duplicados listo.
