# %%
import requests
from bs4 import BeautifulSoup
import time
import csv

# %%
BASE_URL = "https://es.wikipedia.org"
processed_urls = set()

# %%
def obtener_sopa(url, intentos=3):
    """Realiza una solicitud HTTP y devuelve una BeautifulSoup, con reintentos."""
    for intento in range(intentos):
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            return BeautifulSoup(response.text, 'html.parser')
        except requests.exceptions.Timeout:
            print(f"Tiempo de espera agotado para {url}. Reintentando ({intento + 1}/{intentos})...")
            time.sleep(5)
        except requests.RequestException as e:
            print(f"Error al acceder a {url}: {e}")
            return None
    return None


def extraer_familias(sopa):
    """Extrae las familias desde la página principal de categoría."""
    familias = []
    for div in sopa.find_all('div', class_='mw-category-group'):
        for li in div.find_all('li'):
            a_tag = li.find('a')
            if a_tag and 'Familia' in a_tag.text and 'Fundadoras' not in a_tag.text:
                familias.append((a_tag.text.strip(), BASE_URL + a_tag['href']))
    return familias


def extraer_miembros_familia(sopa):
    """
    Extrae recursivamente los miembros de una categoría:
      1) Recorre subcategorías y llama recursivo.
      2) Luego extrae las páginas de 'mw-pages'.
    """
    miembros = set()
    subcat = sopa.find('div', id='mw-subcategories')
    if subcat:
        for div in subcat.find_all('div', class_='mw-category-group'):
            for li in div.find_all('li'):
                a = li.find('a', href=True)
                if a and '/wiki/Categor%C3%ADa:' in a['href']:
                    sub_sopa = obtener_sopa(BASE_URL + a['href'])
                    if sub_sopa:
                        miembros |= extraer_miembros_familia(sub_sopa)
    pages = sopa.find('div', id='mw-pages')
    if pages:
        for div in pages.find_all('div', class_='mw-category-group'):
            for li in div.find_all('li'):
                a = li.find('a', href=True)
                if a:
                    miembros.add((a.text.strip(), BASE_URL + a['href']))
    return miembros


def save_to_csv(info, filename="familias_mexicanas.csv"):
    """Guarda un diccionario en el CSV si su URL no se ha procesado aún."""
    if info["URL"] in processed_urls:
        return
    processed_urls.add(info["URL"])

    with open(filename, mode='a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        row = [
            info.get("Nombre", ""),
            info.get("Fecha de nacimiento", ""),
            info.get("Residencia", ""),
            info.get("Nacionalidad", ""),
            info.get("Cargos", ""),
            info.get("Educación", ""),
            info.get("Trabajos previos", ""),
            info.get("Área", ""),
            info.get("Partido político", ""),
            info.get("Familia", ""),
            info.get("Categorías", ""),
            info.get("URL", "")
        ]
        writer.writerow(row)


def dedup_csv(filename="familias_mexicanas.csv"):
    """Elimina filas duplicadas en el CSV, basándose en todas las columnas."""
    seen = set()
    unique = []
    with open(filename, newline='', encoding='utf-8') as f:
        reader = csv.reader(f, delimiter=';')
        header = next(reader)
        for row in reader:
            row_tup = tuple(row)
            if row_tup not in seen:
                seen.add(row_tup)
                unique.append(row)
    with open(filename, mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        writer.writerow(header)
        writer.writerows(unique)


def extract_info(url, depth=0, max_depth=1):
    sopa = obtener_sopa(url)
    if not sopa:
        return

    infobox = sopa.find("table", class_="infobox biography vcard")
    if not infobox:
        return

    info = {
        "Nombre": "", "Fecha de nacimiento": "", "Residencia": "",
        "Nacionalidad": "", "Cargos": "", "Educación": "",
        "Trabajos previos": "", "Área": "", "Partido político": "",
        "Familia": "", "Categorías": "", "URL": url
    }

    h1 = sopa.find("h1", class_="firstHeading")
    if h1:
        info["Nombre"] = h1.text.strip()

    cat_div = sopa.find("div", id="mw-normal-catlinks")
    if cat_div:
        info["Categorías"] = "; ".join(a.text for a in cat_div.find_all("a"))

    rows = infobox.find_all("tr")
    for row in rows:
        th = row.find("th")
        td = row.find("td")
        if not th or not td:
            continue
        h = th.text.strip()
        txt = td.get_text(" ", strip=True)

        if "Nacimiento" in h:
            info["Fecha de nacimiento"] = txt
        elif "Residencia" in h:
            info["Residencia"] = txt
        elif "Nacionalidad" in h:
            info["Nacionalidad"] = txt
        elif any(k in h for k in ["Ocupación", "Cargo", "Cargos"]):
            info["Cargos"] = "; ".join(td.stripped_strings)
        elif any(k in h for k in ["Educación", "Educado en", "Educada en"]):
            info["Educación"] = "; ".join(
                a.text for a in td.find_all("a", href=True) if a["href"].startswith("/wiki/")
            )
        elif "Área" in h:
            info["Área"] = txt
        elif "Partido político" in h:
            info["Partido político"] = "; ".join(a.text for a in td.find_all("a", href=True))
        elif any(k in h for k in ["Padres", "Cónyuge", "Hijos", "Familia"]):
            familia = []
            for a in td.find_all("a", href=True):
                href = a["href"]
                if href.startswith("/wiki/") and not any(href.startswith(excl) for excl in [
                        "/wiki/Ayuda:", "/wiki/Archivo:", "/wiki/Especial:",
                        "/wiki/Plantilla:", "/wiki/Portal:", "/wiki/Categor%C3%ADa:", "/wiki/Familia_"
                ]):
                    familia.append(f"{a.text} ({BASE_URL}{href})")
            info["Familia"] = "; ".join(familia)

    for i in range(len(rows)-1):
        th = rows[i].find("th")
        td = rows[i+1].find("td")
        if th and td and th.get("colspan") == "3" and "background-color:#E6E6FA" in th.get("style", ""):
            cargos = "; ".join(a.text for a in th.find_all("a", href=True))
            fechas = td.get_text(" ", strip=True)
            info["Trabajos previos"] += f"{cargos} – {fechas}; "

    save_to_csv(info)
    print(f"Guardado: {info['Nombre']}")

    if depth < max_depth and info["Familia"]:
        for miembro in info["Familia"].split("; "):
            if "(" in miembro and miembro.endswith(")"):
                member_url = miembro.split("(")[1][:-1]
                extract_info(member_url, depth+1, max_depth)
                time.sleep(2)

# %%
def main():
    url_categorias = f'{BASE_URL}/wiki/Categor%C3%ADa:Familias_de_M%C3%A9xico'

    # Crear CSV con encabezado
    header = [
        "Nombre", "Fecha de nacimiento", "Residencia", "Nacionalidad",
        "Cargos", "Educación", "Trabajos previos", "Área",
        "Partido político", "Familia", "Categorías", "URL"
    ]
    with open("familias_mexicanas.csv", mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=';')
        writer.writerow(header)

    sopa_principal = obtener_sopa(url_categorias)
    if not sopa_principal:
        print("No se pudo cargar la categoría principal.")
        return

    familias = extraer_familias(sopa_principal)
    for fam_nombre, fam_url in familias:
        print(f"Procesando miembros de {fam_nombre}...")
        sopa_fam = obtener_sopa(fam_url)
        if not sopa_fam:
            continue
        miembros = extraer_miembros_familia(sopa_fam)
        for _, miembro_url in miembros:
            extract_info(miembro_url, depth=0, max_depth=1)
            time.sleep(1)

    # Eliminar duplicados finales
    dedup_csv("familias_mexicanas.csv")
    print("Extracción completa. CSV limpio y sin duplicados listo.")

if __name__ == '__main__':
    main()
# Out:
# Procesando miembros de Familia Aguilar...
# Guardado: Majo Aguilar
# Guardado: Flor Silvestre
# Guardado: La Prieta Linda
# Guardado: Mary Jiménez
# Guardado: Majo Aguilar
# Guardado: Leonardo Aguilar
# Guardado: Ángela Aguilar
# Guardado: Ángela Aguilar
# Guardado: Guadalupe Pineda
# Guardado: Leonardo Aguilar
# Guardado: Pepe Aguilar
# Guardado: Antonio Aguilar hijo
# Guardado: Antonio Aguilar
# Procesando miembros de Familia Álvarez del Castillo...
# Guardado: Enrique Álvarez del Castillo
# Guardado: Juan Manuel Álvarez del Castillo
# Procesando miembros de Familia Bichir...
# Guardado: Maricruz Nájera
# Guardado: Demián Bichir
# Guardado: Bruno Bichir
# Guardado: Odiseo Bichir
# Guardado: Demián Bichir
# Guardado: Odiseo Bichir
# Guardado: Maricruz Nájera
# Guardado: Bruno Bichir
# Guardado: Maricruz Nájera
# Procesando miembros de Familia Calderón Hinojosa...
# Guardado: Luis Calderón Vega
# Guardado: Luisa María Calderón Hinojosa
# Guardado: Felipe Calderón
# Guardado: Margarita Zavala
# Guardado: Felipe Calderón
# Guardado: Luisa María Calderón Hinojosa
# Guardado: Margarita Zavala
# Procesando miembros de Familia Capetillo...
# Guardado: Biby Gaytán
# Guardado: Guillermo Capetillo
# Guardado: Eduardo Capetillo
# Guardado: Manuel Capetillo
# Guardado: Manuel Capetillo de Flores
# Guardado: Guillermo Capetillo
# Guardado: Eduardo Capetillo
# Guardado: Manuel Capetillo de Flores
# Guardado: Manuel Capetillo
# Procesando miembros de Familia Cárdenas...
# Guardado: Amalia Solórzano
# Guardado: Cuauhtémoc Cárdenas
# Guardado: Santiago Cárdenas
# Guardado: Juan Cárdenas Arroyo
# Guardado: Camilo Torres Tenorio
# Guardado: Juan Eduardo Jaramillo
# Guardado: Tomás Cipriano de Mosquera
# Guardado: Joaquín Mosquera
# Guardado: Juan Cárdenas Arroyo
# Guardado: Santiago Cárdenas
# Guardado: Tomás Cipriano de Mosquera
# Guardado: Dámaso Cárdenas del Río
# Guardado: Cuauhtémoc Cárdenas
# Guardado: Lázaro Cárdenas Batel
# Guardado: Lázaro Cárdenas
# Guardado: Cuauhtémoc Cárdenas
# Guardado: Lázaro Cárdenas Batel
# Guardado: Lázaro Cárdenas
# Procesando miembros de Familia Carranza...
# Guardado: Alberto Salinas Carranza
# Guardado: Erasto Carranza Castro
# Guardado: Emilio Carranza
# Guardado: Abelardo Carranza Strasburger
# Guardado: Rafael Carranza Hernández
# Guardado: Ignacio Peraldí Carranza
# Guardado: Fernando Peraldí Carranza
# Guardado: Jesús Carranza Castro
# Guardado: Moisés Carranza Castro
# Guardado: Jesús Carranza Garza
# Guardado: Abelardo Carranza Strasburger
# Guardado: Jesús Carranza Neira
# Guardado: Venustiano Carranza
# Guardado: Jesús Carranza Garza
# Guardado: Venustiano Carranza
# Guardado: Rafael Carranza Hernández
# Guardado: Carlos Abascal Carranza
# Guardado: Sebastián Carranza Cepeda
# Procesando miembros de Familia Creel-Terrazas...
# Guardado: Alberto Terrazas Cuilty
# Guardado: Santiago Creel
# Guardado: Juan Terrazas Cuilty
# Guardado: Enrique C. Creel
# Guardado: Santiago Creel
# Guardado: Luis Terrazas
# Procesando miembros de Familia del Mazo...
# Guardado: Alfredo del Mazo González
# Guardado: Alfredo del Mazo Maza
# Guardado: Alfredo del Mazo Vélez
# Guardado: Alfredo del Mazo González
# Guardado: Alfredo del Mazo Maza
# Guardado: Carolina Monroy del Mazo
# Guardado: Alfredo del Mazo Maza
# Guardado: Enrique Peña Nieto
# Guardado: Alfredo del Mazo González
# Procesando miembros de Familia Díaz...
# Guardado: Porfirio Díaz
# Guardado: Amada Díaz
# Guardado: Porfirio Díaz Ortega
# Guardado: Carmen Romero Rubio
# Guardado: Porfirio Díaz
# Guardado: Delfina Ortega Díaz
# Guardado: Porfirio Díaz Ortega
# Guardado: Porfirio Díaz Ortega
# Guardado: Félix Díaz
# Guardado: Ignacio de la Torre y Mier
# Guardado: Amada Díaz
# Guardado: Ignacio de la Torre y Mier
# Guardado: Félix Díaz Mori
# Guardado: Félix Díaz
# Procesando miembros de Familia Farías...
# Guardado: Ernesto Madero Farías
# Guardado: Gregorio Farías Longoria
# Guardado: Andrés Farías Benavides
# Guardado: Luis M. Farías
# Guardado: Juan Francisco de Farías y Sánchez de Uribe
# Guardado: Francisco Fuentes Farías
# Procesando miembros de Familia Galeana...
# Guardado: Pablo Galeana
# Guardado: Fermín Galeana
# Guardado: Hermenegildo Galeana
# Guardado: Antonio Galeana
# Procesando miembros de Familia González Guevara...
# Guardado: Rodolfo González Guevara
# Guardado: Héctor González Guevara
# Guardado: Antonio González Guevara
# Procesando miembros de Familia González Torres...
# Guardado: Jorge Emilio González Martínez
# Guardado: Jorge González Torres
# Guardado: Jorge Emilio González Martínez
# Guardado: José Antonio Arévalo González
# Guardado: Xavier González Zirión
# Guardado: Víctor González Torres
# Guardado: Jorge González Torres
# Guardado: Jorge Emilio González Martínez
# Procesando miembros de Familia Guerrero...
# Guardado: Eddie Guerrero
# Guardado: Shaul Guerrero
# Procesando miembros de Familia Guízar...
# Guardado: Jesús Degollado Guízar
# Guardado: Tito Guízar
# Guardado: Susana Guízar
# Guardado: Pepe Guízar
# Procesando miembros de Familia Guzmán...
# Guardado: Joaquín Guzmán López
# Guardado: Ovidio Guzmán López
# Guardado: Iván Archivaldo Guzmán Salazar
# Guardado: Jesús Alfredo Guzmán Salazar
# Guardado: Ovidio Guzmán López
# Guardado: Joaquín Guzmán López
# Guardado: Iván Archivaldo Guzmán Salazar
# Guardado: Jesús Alfredo Guzmán Salazar
# Guardado: Iván Archivaldo Guzmán Salazar
# Guardado: Jesús Alfredo Guzmán Salazar
# Guardado: Ovidio Guzmán López
# Guardado: Joaquín Guzmán López
# Guardado: Jesús Alfredo Guzmán Salazar
# Guardado: Iván Archivaldo Guzmán Salazar
# Guardado: Ovidio Guzmán López
# Guardado: Joaquín Guzmán López
# Guardado: Joaquín Guzmán Loera
# Guardado: Iván Archivaldo Guzmán Salazar
# Guardado: Jesús Alfredo Guzmán Salazar
# Guardado: Joaquín Guzmán López
# Guardado: Ovidio Guzmán López
# Procesando miembros de Familia LeBaron...
# Guardado: Alma Dayer LeBaron
# Guardado: Ervil LeBaron
# Guardado: Álex LeBarón
# Procesando miembros de Familia López-Portillo...
# Guardado: Margarita López Portillo
# Guardado: José López Portillo
# Guardado: José López Portillo y Rojas
# Guardado: José López Portillo y Weber
# Guardado: Jesús López Portillo
# Guardado: José López Portillo y Rojas
# Guardado: Carmen Romano
# Guardado: José López Portillo y Weber
# Guardado: José López Portillo
# Procesando miembros de Familia Martín del Campo...
# Guardado: Rafael Martín del Campo
# Guardado: Juan Manuel Martín del Campo
# Guardado: Carlos Martín del Campo
# Guardado: María del Carmen Martín del Campo
# Guardado: Francisco Martín del Campo
# Procesando miembros de Familia Moctezuma...
# Guardado: Leonor Cortés Moctezuma
# Guardado: Juan de Tolosa
# Procesando miembros de Familia Monreal...
# Guardado: Saúl Monreal Ávila
# Guardado: Ricardo Monreal Ávila
# Guardado: David Monreal Ávila
# Guardado: Susana Monreal Ávila
# Guardado: David Monreal Ávila
# Guardado: Ricardo Monreal Ávila
# Guardado: David Monreal Ávila
# Guardado: Susana Monreal Ávila
# Guardado: Saúl Monreal Ávila
# Guardado: Magdalena Núñez Monreal
# Procesando miembros de Familia Moreno Valle...
# Guardado: Martha Érika Alonso
# Guardado: Rafael Moreno Valle Rosas
# Guardado: Rafael Moreno Valle Rosas
# Guardado: Rafael Moreno Valle
# Guardado: Rafael Moreno Valle
# Procesando miembros de Familia Muñoz Ledo...
# Guardado: Porfirio Thierry Muñoz Ledo
# Guardado: Libia García Muñoz Ledo
# Guardado: Porfirio Muñoz Ledo
# Guardado: Porfirio Thierry Muñoz Ledo
# Guardado: Jesús Cabrera Muñoz Ledo
# Procesando miembros de Familia Pinal Hidalgo...
# Guardado: Sylvia Pasquel
# Guardado: Silvia Pinal
# Guardado: Viridiana Alatriste
# Guardado: Alejandra Guzmán
# Guardado: Camila Valero
# Guardado: Stephanie Salas
# Procesando miembros de Familia Revueltas Sánchez...
# Guardado: Silvestre Revueltas
# Guardado: Andrea Revueltas
# Guardado: José Revueltas
# Guardado: Silvestre Revueltas
# Guardado: Fermín Revueltas
# Guardado: Rosaura Revueltas
# Guardado: Fermín Revueltas
# Guardado: Rosaura Revueltas
# Procesando miembros de Familia Reyes Larios...
# Guardado: Melitón Reyes Larios
# Guardado: Melitón Reyes Andrade
# Guardado: Melitón Reyes Larios
# Procesando miembros de Familia Salinas...
# Guardado: Carlos Salinas de Gortari
# Guardado: Raúl Salinas de Gortari
# Guardado: Enrique Salinas de Gortari
# Guardado: Claudia Ruiz Massieu Salinas
# Guardado: Raúl Salinas Lozano
# Guardado: Raúl Salinas de Gortari
# Guardado: Carlos Salinas de Gortari
# Guardado: Enrique Salinas de Gortari
# Guardado: Enrique Salinas de Gortari
# Guardado: Raúl Salinas de Gortari
# Guardado: Carlos Salinas de Gortari
# Guardado: Enrique Salinas de Gortari
# Procesando miembros de Familia Sodi...
# Guardado: Demetrio Sodi Guergué
# Guardado: Gabriela Sodi Miranda
# Guardado: Camila Sodi
# Guardado: Federico Sodi Romero
# Guardado: Demetrio Sodi de la Tijera
# Guardado: Carlos Franco Sodi
# Guardado: Ernestina Sodi
# Guardado: Thalía
# Guardado: Carlos Sodi Candiani
# Procesando miembros de Familia Soler...
# Guardado: Mercedes Soler (actriz)
# Guardado: Julián Soler
# Guardado: Fernando Soler
# Guardado: Andrés Soler
# Guardado: Domingo Soler
# Procesando miembros de Familia Valdés...
# Guardado: Germán Valdés
# Guardado: Ramón Valdés
# Guardado: Araceli Julián
# Guardado: Germán Valdés III
# Guardado: Kevin Holt
# Guardado: Antonio Valdés (actor)
# Guardado: Germán Valdés
# Guardado: Ramón Valdés
# Guardado: Araceli Julián
# Guardado: Rosalía Julián
# Guardado: Ramón Valdés
# Guardado: Germán Valdés
# Guardado: Rosalía Julián
# Guardado: Germán Valdés III
# Guardado: Manuel Valdés (actor)
# Guardado: Germán Valdés
# Guardado: Ramón Valdés
# Guardado: Araceli Julián
# Guardado: Rosalía Julián
# Guardado: Cristian Castro
# Guardado: Germán Valdés
# Guardado: Ramón Valdés
# Guardado: Rosalía Valdés
# Guardado: José Alberto Castro
# Guardado: Sofía Castro
# Guardado: Rosalía Valdés
# Guardado: Ramón Valdés
# Guardado: Cristian Castro
# Procesando miembros de Familia Yunes...
# Guardado: Patricia Lobeira Rodríguez
# Guardado: Miguel Ángel Yunes Linares
# Guardado: Héctor Yunes Landa
# Guardado: Miguel Ángel Yunes Márquez
# Guardado: Patricia Lobeira Rodríguez
# Guardado: Fernando Yunes Márquez
# Guardado: Miguel Ángel Yunes Márquez
# Guardado: José Francisco Yunes Zorrilla
# Guardado: Héctor Yunes Landa
# Guardado: Miguel Ángel Yunes Linares
# Guardado: Miguel Ángel Yunes Márquez
# Guardado: Fernando Yunes Márquez
# Procesando miembros de Familia Echave...
# Procesando miembros de Familia Martínez del Río...
# Procesando miembros de Familia Ortega y Bonilla...
# Extracción completa. CSV limpio y sin duplicados listo.
